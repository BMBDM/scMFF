# %% [markdown]
# # Usage Example

# %%
from scMFF_pipeline import *
dir = 'Example_data/'
model_name = 'KNN'

scMFF_model(dir, model_name)
# Out:
# ---------------------------------------------------------------
# Step 0: Data loading in progress...
# Data loading complete.
# ---------------------------------------------------------------
# Step 1: Data preprocessing in progress...
# /home/sunnan/anaconda3/envs/SunNan_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /mnt/202001Main/BioData/Transcriptome_classification/scMFF/scMFF/Preprocessing.py:8: DeprecationWarning: `log1p` is deprecated since scVelo v0.3.0 and will be removed in a future version. Please use `log1p` from `scanpy.pp` instead.
#   scv.pp.log1p(adata)
# Extracted 2000 highly variable genes.
# Data preprocessing complete.
# ---------------------------------------------------------------
# Step 2: Feature extraction in progress...
# (1) Statistics-based Feature: expr_2000.csv 	 (2998, 2000)
# (2) Information-based Feature: scPSD_embedding.txt.gz 	 (2998, 2000)
# (3) Matrix Factorization-based Feature: PCA_embedding.txt.gz 	 (2998, 266)
# Step1: Start filter and generating CSV
# Input scRNA data in CSV format is validated, start reading...
# Data loaded, start filtering...
# After preprocessing, 14118 genes remaining
# After preprocessing, 2998 cells have 0.99 nonzero
# Preprocessing Done. Total Running Time: 10.907299757003784 seconds
# 2025-05-15 15:16:41.514569: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using device:cuda
# ---0:00:00---scRNA starts loading.
# Load expression in csv format
# ---0:00:02---scRNA has been successfully loaded
# ---0:00:02---TrainLoader has been successfully prepared.
# ---0:00:03---Pytorch model ready.
# Start training...
# Train Epoch: 1 [0/2998 (0%)]	Loss: 237.400246
# ====> Epoch: 1 Average loss: 237.4002
# Train Epoch: 2 [0/2998 (0%)]	Loss: 198.652643
# ====> Epoch: 2 Average loss: 198.6526
# Train Epoch: 3 [0/2998 (0%)]	Loss: 189.751564
# ====> Epoch: 3 Average loss: 189.7516
# Train Epoch: 4 [0/2998 (0%)]	Loss: 149.167591
# ====> Epoch: 4 Average loss: 149.1676
# Train Epoch: 5 [0/2998 (0%)]	Loss: 138.537483
# ====> Epoch: 5 Average loss: 138.5375
# Train Epoch: 6 [0/2998 (0%)]	Loss: 128.193358
# ====> Epoch: 6 Average loss: 128.1934
# Train Epoch: 7 [0/2998 (0%)]	Loss: 125.429661
# ====> Epoch: 7 Average loss: 125.4297
# Train Epoch: 8 [0/2998 (0%)]	Loss: 120.841186
# ====> Epoch: 8 Average loss: 120.8412
# Train Epoch: 9 [0/2998 (0%)]	Loss: 114.851484
# ====> Epoch: 9 Average loss: 114.8515
# Train Epoch: 10 [0/2998 (0%)]	Loss: 113.518293
# ====> Epoch: 10 Average loss: 113.5183
# Train Epoch: 11 [0/2998 (0%)]	Loss: 111.102839
# ====> Epoch: 11 Average loss: 111.1028
# Train Epoch: 12 [0/2998 (0%)]	Loss: 108.406729
# ====> Epoch: 12 Average loss: 108.4067
# Train Epoch: 13 [0/2998 (0%)]	Loss: 107.589372
# ====> Epoch: 13 Average loss: 107.5894
# Train Epoch: 14 [0/2998 (0%)]	Loss: 104.732311
# ====> Epoch: 14 Average loss: 104.7323
# Train Epoch: 15 [0/2998 (0%)]	Loss: 102.269388
# ====> Epoch: 15 Average loss: 102.2694
# Train Epoch: 16 [0/2998 (0%)]	Loss: 100.919801
# ====> Epoch: 16 Average loss: 100.9198
# Train Epoch: 17 [0/2998 (0%)]	Loss: 98.593323
# ====> Epoch: 17 Average loss: 98.5933
# Train Epoch: 18 [0/2998 (0%)]	Loss: 96.859854
# ====> Epoch: 18 Average loss: 96.8599
# Train Epoch: 19 [0/2998 (0%)]	Loss: 95.349817
# ====> Epoch: 19 Average loss: 95.3498
# Train Epoch: 20 [0/2998 (0%)]	Loss: 92.962788
# ====> Epoch: 20 Average loss: 92.9628
# Train Epoch: 21 [0/2998 (0%)]	Loss: 91.304526
# ====> Epoch: 21 Average loss: 91.3045
# Train Epoch: 22 [0/2998 (0%)]	Loss: 89.451530
# ====> Epoch: 22 Average loss: 89.4515
# Train Epoch: 23 [0/2998 (0%)]	Loss: 87.650924
# ====> Epoch: 23 Average loss: 87.6509
# Train Epoch: 24 [0/2998 (0%)]	Loss: 86.398182
# ====> Epoch: 24 Average loss: 86.3982
# Train Epoch: 25 [0/2998 (0%)]	Loss: 84.694051
# ====> Epoch: 25 Average loss: 84.6941
# Train Epoch: 26 [0/2998 (0%)]	Loss: 83.338966
# ====> Epoch: 26 Average loss: 83.3390
# Train Epoch: 27 [0/2998 (0%)]	Loss: 82.016714
# ====> Epoch: 27 Average loss: 82.0167
# Train Epoch: 28 [0/2998 (0%)]	Loss: 80.529296
# ====> Epoch: 28 Average loss: 80.5293
# Train Epoch: 29 [0/2998 (0%)]	Loss: 79.350077
# ====> Epoch: 29 Average loss: 79.3501
# Train Epoch: 30 [0/2998 (0%)]	Loss: 77.815460
# ====> Epoch: 30 Average loss: 77.8155
# Train Epoch: 31 [0/2998 (0%)]	Loss: 76.379753
# ====> Epoch: 31 Average loss: 76.3798
# Train Epoch: 32 [0/2998 (0%)]	Loss: 74.787655
# ====> Epoch: 32 Average loss: 74.7877
# Train Epoch: 33 [0/2998 (0%)]	Loss: 73.219073
# ====> Epoch: 33 Average loss: 73.2191
# Train Epoch: 34 [0/2998 (0%)]	Loss: 71.889072
# ====> Epoch: 34 Average loss: 71.8891
# Train Epoch: 35 [0/2998 (0%)]	Loss: 70.469907
# ====> Epoch: 35 Average loss: 70.4699
# Train Epoch: 36 [0/2998 (0%)]	Loss: 69.076588
# ====> Epoch: 36 Average loss: 69.0766
# Train Epoch: 37 [0/2998 (0%)]	Loss: 67.623416
# ====> Epoch: 37 Average loss: 67.6234
# Train Epoch: 38 [0/2998 (0%)]	Loss: 66.211370
# ====> Epoch: 38 Average loss: 66.2114
# Train Epoch: 39 [0/2998 (0%)]	Loss: 64.742339
# ====> Epoch: 39 Average loss: 64.7423
# Train Epoch: 40 [0/2998 (0%)]	Loss: 63.232895
# ====> Epoch: 40 Average loss: 63.2329
# Train Epoch: 41 [0/2998 (0%)]	Loss: 61.692957
# ====> Epoch: 41 Average loss: 61.6930
# Train Epoch: 42 [0/2998 (0%)]	Loss: 60.281823
# ====> Epoch: 42 Average loss: 60.2818
# Train Epoch: 43 [0/2998 (0%)]	Loss: 58.820161
# ====> Epoch: 43 Average loss: 58.8202
# Train Epoch: 44 [0/2998 (0%)]	Loss: 57.507151
# ====> Epoch: 44 Average loss: 57.5072
# Train Epoch: 45 [0/2998 (0%)]	Loss: 56.344084
# ====> Epoch: 45 Average loss: 56.3441
# Train Epoch: 46 [0/2998 (0%)]	Loss: 55.310447
# ====> Epoch: 46 Average loss: 55.3104
# Train Epoch: 47 [0/2998 (0%)]	Loss: 54.387868
# ====> Epoch: 47 Average loss: 54.3879
# Train Epoch: 48 [0/2998 (0%)]	Loss: 53.537004
# ====> Epoch: 48 Average loss: 53.5370
# Train Epoch: 49 [0/2998 (0%)]	Loss: 52.845981
# ====> Epoch: 49 Average loss: 52.8460
# Train Epoch: 50 [0/2998 (0%)]	Loss: 52.272958
# ====> Epoch: 50 Average loss: 52.2730
# zOut ready at 11.17458987236023
# ---0:00:11---Start Prune
# Start pruning 0th cell, cost 8.559226989746094e-05s
# ---0:00:12---Prune Finished
# ---0:00:12---EM process starts
# ---0:00:12---Start 0th iteration.
# Louvain cluster: 22
# ---0:00:13---Clustering Ends
# Total Cluster Number: 11
# Train Epoch: 1 [0/2998 (0%)]	Loss: 51.824623
# ====> Epoch: 1 Average loss: 51.8246
# Train Epoch: 2 [0/2998 (0%)]	Loss: 51.448361
# ====> Epoch: 2 Average loss: 51.4484
# Train Epoch: 3 [0/2998 (0%)]	Loss: 51.128231
# ====> Epoch: 3 Average loss: 51.1282
# Train Epoch: 4 [0/2998 (0%)]	Loss: 50.848112
# ====> Epoch: 4 Average loss: 50.8481
# Train Epoch: 5 [0/2998 (0%)]	Loss: 50.608885
# ====> Epoch: 5 Average loss: 50.6089
# Train Epoch: 6 [0/2998 (0%)]	Loss: 50.404957
# ====> Epoch: 6 Average loss: 50.4050
# Train Epoch: 7 [0/2998 (0%)]	Loss: 50.213001
# ====> Epoch: 7 Average loss: 50.2130
# Train Epoch: 8 [0/2998 (0%)]	Loss: 50.031208
# ====> Epoch: 8 Average loss: 50.0312
# Train Epoch: 9 [0/2998 (0%)]	Loss: 49.835891
# ====> Epoch: 9 Average loss: 49.8359
# Train Epoch: 10 [0/2998 (0%)]	Loss: 49.636862
# ====> Epoch: 10 Average loss: 49.6369
# Train Epoch: 11 [0/2998 (0%)]	Loss: 49.442097
# ====> Epoch: 11 Average loss: 49.4421
# Train Epoch: 12 [0/2998 (0%)]	Loss: 49.250141
# ====> Epoch: 12 Average loss: 49.2501
# Train Epoch: 13 [0/2998 (0%)]	Loss: 49.073497
# ====> Epoch: 13 Average loss: 49.0735
# Train Epoch: 14 [0/2998 (0%)]	Loss: 48.908533
# ====> Epoch: 14 Average loss: 48.9085
# Train Epoch: 15 [0/2998 (0%)]	Loss: 48.748838
# ====> Epoch: 15 Average loss: 48.7488
# Train Epoch: 16 [0/2998 (0%)]	Loss: 48.602433
# ====> Epoch: 16 Average loss: 48.6024
# Train Epoch: 17 [0/2998 (0%)]	Loss: 48.465586
# ====> Epoch: 17 Average loss: 48.4656
# Train Epoch: 18 [0/2998 (0%)]	Loss: 48.323966
# ====> Epoch: 18 Average loss: 48.3240
# Train Epoch: 19 [0/2998 (0%)]	Loss: 48.163432
# ====> Epoch: 19 Average loss: 48.1634
# Train Epoch: 20 [0/2998 (0%)]	Loss: 47.984995
# ====> Epoch: 20 Average loss: 47.9850
# ---0:00:17---Start Prune
# Start pruning 0th cell, cost 3.600120544433594e-05s
# ---0:00:18---Prune Finished
# ---0:00:18---Start test converge condition
# celltype similarity:0.0
# ---0:00:18---0th iteration in EM Finished
# ---0:00:18---Start 1th iteration.
# Louvain cluster: 22
# ---0:00:19---Clustering Ends
# Total Cluster Number: 11
# Train Epoch: 1 [0/2998 (0%)]	Loss: 47.813667
# ====> Epoch: 1 Average loss: 47.8137
# Train Epoch: 2 [0/2998 (0%)]	Loss: 47.668268
# ====> Epoch: 2 Average loss: 47.6683
# Train Epoch: 3 [0/2998 (0%)]	Loss: 47.550841
# ====> Epoch: 3 Average loss: 47.5508
# Train Epoch: 4 [0/2998 (0%)]	Loss: 47.451999
# ====> Epoch: 4 Average loss: 47.4520
# Train Epoch: 5 [0/2998 (0%)]	Loss: 47.367651
# ====> Epoch: 5 Average loss: 47.3677
# Train Epoch: 6 [0/2998 (0%)]	Loss: 47.292070
# ====> Epoch: 6 Average loss: 47.2921
# Train Epoch: 7 [0/2998 (0%)]	Loss: 47.151127
# ====> Epoch: 7 Average loss: 47.1511
# Train Epoch: 8 [0/2998 (0%)]	Loss: 46.953849
# ====> Epoch: 8 Average loss: 46.9538
# Train Epoch: 9 [0/2998 (0%)]	Loss: 46.773964
# ====> Epoch: 9 Average loss: 46.7740
# Train Epoch: 10 [0/2998 (0%)]	Loss: 46.675263
# ====> Epoch: 10 Average loss: 46.6753
# Train Epoch: 11 [0/2998 (0%)]	Loss: 46.591947
# ====> Epoch: 11 Average loss: 46.5919
# Train Epoch: 12 [0/2998 (0%)]	Loss: 46.449101
# ====> Epoch: 12 Average loss: 46.4491
# Train Epoch: 13 [0/2998 (0%)]	Loss: 46.269992
# ====> Epoch: 13 Average loss: 46.2700
# Train Epoch: 14 [0/2998 (0%)]	Loss: 46.104929
# ====> Epoch: 14 Average loss: 46.1049
# Train Epoch: 15 [0/2998 (0%)]	Loss: 45.977620
# ====> Epoch: 15 Average loss: 45.9776
# Train Epoch: 16 [0/2998 (0%)]	Loss: 45.884887
# ====> Epoch: 16 Average loss: 45.8849
# Train Epoch: 17 [0/2998 (0%)]	Loss: 45.836162
# ====> Epoch: 17 Average loss: 45.8362
# Train Epoch: 18 [0/2998 (0%)]	Loss: 45.810978
# ====> Epoch: 18 Average loss: 45.8110
# Train Epoch: 19 [0/2998 (0%)]	Loss: 45.653034
# ====> Epoch: 19 Average loss: 45.6530
# Train Epoch: 20 [0/2998 (0%)]	Loss: 45.418154
# ====> Epoch: 20 Average loss: 45.4182
# ---0:00:23---Start Prune
# Start pruning 0th cell, cost 8.726119995117188e-05s
# ---0:00:25---Prune Finished
# ---0:00:25---Start test converge condition
# celltype similarity:0.7571773857253645
# ---0:00:25---1th iteration in EM Finished
# ---0:00:25---Starts Imputation
# Train Epoch: 1 [0/2998 (0%)]	Loss: 76300.717812
# ====> Epoch: 1 Average loss: 76300.7178
# Train Epoch: 2 [0/2998 (0%)]	Loss: 64858.300200
# ====> Epoch: 2 Average loss: 64858.3002
# Train Epoch: 3 [0/2998 (0%)]	Loss: 60873.446298
# ====> Epoch: 3 Average loss: 60873.4463
# Train Epoch: 4 [0/2998 (0%)]	Loss: 48436.002668
# ====> Epoch: 4 Average loss: 48436.0027
# Train Epoch: 5 [0/2998 (0%)]	Loss: 44005.715811
# ====> Epoch: 5 Average loss: 44005.7158
# Train Epoch: 6 [0/2998 (0%)]	Loss: 39775.423616
# ====> Epoch: 6 Average loss: 39775.4236
# Train Epoch: 7 [0/2998 (0%)]	Loss: 38338.305537
# ====> Epoch: 7 Average loss: 38338.3055
# Train Epoch: 8 [0/2998 (0%)]	Loss: 35476.280187
# ====> Epoch: 8 Average loss: 35476.2802
# Train Epoch: 9 [0/2998 (0%)]	Loss: 33564.005337
# ====> Epoch: 9 Average loss: 33564.0053
# Train Epoch: 10 [0/2998 (0%)]	Loss: 32571.935957
# ====> Epoch: 10 Average loss: 32571.9360
# Train Epoch: 11 [0/2998 (0%)]	Loss: 31377.286191
# ====> Epoch: 11 Average loss: 31377.2862
# Train Epoch: 12 [0/2998 (0%)]	Loss: 30896.221481
# ====> Epoch: 12 Average loss: 30896.2215
# Train Epoch: 13 [0/2998 (0%)]	Loss: 30052.061374
# ====> Epoch: 13 Average loss: 30052.0614
# Train Epoch: 14 [0/2998 (0%)]	Loss: 29128.867245
# ====> Epoch: 14 Average loss: 29128.8672
# Train Epoch: 15 [0/2998 (0%)]	Loss: 28603.551701
# ====> Epoch: 15 Average loss: 28603.5517
# Train Epoch: 16 [0/2998 (0%)]	Loss: 27841.256838
# ====> Epoch: 16 Average loss: 27841.2568
# Train Epoch: 17 [0/2998 (0%)]	Loss: 27201.299533
# ====> Epoch: 17 Average loss: 27201.2995
# Train Epoch: 18 [0/2998 (0%)]	Loss: 26513.683789
# ====> Epoch: 18 Average loss: 26513.6838
# Train Epoch: 19 [0/2998 (0%)]	Loss: 25718.270847
# ====> Epoch: 19 Average loss: 25718.2708
# Train Epoch: 20 [0/2998 (0%)]	Loss: 25167.068712
# ====> Epoch: 20 Average loss: 25167.0687
# ---0:00:29---All iterations finished, start output results.
# ---0:00:30---scGNN finished
# (4) Deep Learningg-based Feature: scGNN_embedding.csv 	 (2998, 128)
# Feature extraction complete.
# ---------------------------------------------------------------
# Step 3: Cross Fusion in progress...
# The 1-th cell embedding
# The 2-th cell embedding
# The 3-th cell embedding
# The 4-th cell embedding
# The 5-th cell embedding
# The 6-th cell embedding
# The 7-th cell embedding
# The 8-th cell embedding
# The 9-th cell embedding
# The 10-th cell embedding
# The 11-th cell embedding
# The 12-th cell embedding
# The 13-th cell embedding
# The 14-th cell embedding
# The 15-th cell embedding
# The 16-th cell embedding
# The 17-th cell embedding
# The 18-th cell embedding
# The 19-th cell embedding
# The 20-th cell embedding
# The 21-th cell embedding
# The 22-th cell embedding
# The 23-th cell embedding
# The 24-th cell embedding
# The 25-th cell embedding
# The 26-th cell embedding
# The 27-th cell embedding
# The 28-th cell embedding
# The 29-th cell embedding
# The 30-th cell embedding
# The 31-th cell embedding
# The 32-th cell embedding
# The 33-th cell embedding
# The 34-th cell embedding
# The 35-th cell embedding
# The 36-th cell embedding
# The 37-th cell embedding
# The 38-th cell embedding
# The 39-th cell embedding
# The 40-th cell embedding
# The 41-th cell embedding
# The 42-th cell embedding
# The 43-th cell embedding
# The 44-th cell embedding
# The 45-th cell embedding
# The 46-th cell embedding
# The 47-th cell embedding
# The 48-th cell embedding
# The 49-th cell embedding
# The 50-th cell embedding
# The 51-th cell embedding
# The 52-th cell embedding
# The 53-th cell embedding
# The 54-th cell embedding
# The 55-th cell embedding
# The 56-th cell embedding
# The 57-th cell embedding
# The 58-th cell embedding
# The 59-th cell embedding
# The 60-th cell embedding
# The 61-th cell embedding
# The 62-th cell embedding
# The 63-th cell embedding
# The 64-th cell embedding
# The 65-th cell embedding
# The 66-th cell embedding
# The 67-th cell embedding
# The 68-th cell embedding
# The 69-th cell embedding
# The 70-th cell embedding
# The 71-th cell embedding
# The 72-th cell embedding
# The 73-th cell embedding
# The 74-th cell embedding
# The 75-th cell embedding
# The 76-th cell embedding
# The 77-th cell embedding
# The 78-th cell embedding
# The 79-th cell embedding
# The 80-th cell embedding
# The 81-th cell embedding
# The 82-th cell embedding
# The 83-th cell embedding
# The 84-th cell embedding
# The 85-th cell embedding
# The 86-th cell embedding
# The 87-th cell embedding
# The 88-th cell embedding
# The 89-th cell embedding
# The 90-th cell embedding
# The 91-th cell embedding
# The 92-th cell embedding
# The 93-th cell embedding
# The 94-th cell embedding
# The 95-th cell embedding
# The 96-th cell embedding
# The 97-th cell embedding
# The 98-th cell embedding
# The 99-th cell embedding
# The 100-th cell embedding
# The 101-th cell embedding
# The 102-th cell embedding
# The 103-th cell embedding
# The 104-th cell embedding
# The 105-th cell embedding
# The 106-th cell embedding
# The 107-th cell embedding
# The 108-th cell embedding
# The 109-th cell embedding
# The 110-th cell embedding
# The 111-th cell embedding
# The 112-th cell embedding
# The 113-th cell embedding
# The 114-th cell embedding
# The 115-th cell embedding
# The 116-th cell embedding
# The 117-th cell embedding
# The 118-th cell embedding
# The 119-th cell embedding
# The 120-th cell embedding
# The 121-th cell embedding
# The 122-th cell embedding
# The 123-th cell embedding
# The 124-th cell embedding
# The 125-th cell embedding
# The 126-th cell embedding
# The 127-th cell embedding
# The 128-th cell embedding
# The 129-th cell embedding
# The 130-th cell embedding
# The 131-th cell embedding
# The 132-th cell embedding
# The 133-th cell embedding
# The 134-th cell embedding
# The 135-th cell embedding
# The 136-th cell embedding
# The 137-th cell embedding
# The 138-th cell embedding
# The 139-th cell embedding
# The 140-th cell embedding
# The 141-th cell embedding
# The 142-th cell embedding
# The 143-th cell embedding
# The 144-th cell embedding
# The 145-th cell embedding
# The 146-th cell embedding
# The 147-th cell embedding
# The 148-th cell embedding
# The 149-th cell embedding
# The 150-th cell embedding
# The 151-th cell embedding
# The 152-th cell embedding
# The 153-th cell embedding
# The 154-th cell embedding
# The 155-th cell embedding
# The 156-th cell embedding
# The 157-th cell embedding
# The 158-th cell embedding
# The 159-th cell embedding
# The 160-th cell embedding
# The 161-th cell embedding
# The 162-th cell embedding
# The 163-th cell embedding
# The 164-th cell embedding
# The 165-th cell embedding
# The 166-th cell embedding
# The 167-th cell embedding
# The 168-th cell embedding
# The 169-th cell embedding
# The 170-th cell embedding
# The 171-th cell embedding
# The 172-th cell embedding
# The 173-th cell embedding
# The 174-th cell embedding
# The 175-th cell embedding
# The 176-th cell embedding
# The 177-th cell embedding
# The 178-th cell embedding
# The 179-th cell embedding
# The 180-th cell embedding
# The 181-th cell embedding
# The 182-th cell embedding
# The 183-th cell embedding
# The 184-th cell embedding
# The 185-th cell embedding
# The 186-th cell embedding
# The 187-th cell embedding
# The 188-th cell embedding
# The 189-th cell embedding
# The 190-th cell embedding
# The 191-th cell embedding
# The 192-th cell embedding
# The 193-th cell embedding
# The 194-th cell embedding
# The 195-th cell embedding
# The 196-th cell embedding
# The 197-th cell embedding
# The 198-th cell embedding
# The 199-th cell embedding
# The 200-th cell embedding
# The 201-th cell embedding
# The 202-th cell embedding
# The 203-th cell embedding
# The 204-th cell embedding
# The 205-th cell embedding
# The 206-th cell embedding
# The 207-th cell embedding
# The 208-th cell embedding
# The 209-th cell embedding
# The 210-th cell embedding
# The 211-th cell embedding
# The 212-th cell embedding
# The 213-th cell embedding
# The 214-th cell embedding
# The 215-th cell embedding
# The 216-th cell embedding
# The 217-th cell embedding
# The 218-th cell embedding
# The 219-th cell embedding
# The 220-th cell embedding
# The 221-th cell embedding
# The 222-th cell embedding
# The 223-th cell embedding
# The 224-th cell embedding
# The 225-th cell embedding
# The 226-th cell embedding
# The 227-th cell embedding
# The 228-th cell embedding
# The 229-th cell embedding
# The 230-th cell embedding
# The 231-th cell embedding
# The 232-th cell embedding
# The 233-th cell embedding
# The 234-th cell embedding
# The 235-th cell embedding
# The 236-th cell embedding
# The 237-th cell embedding
# The 238-th cell embedding
# The 239-th cell embedding
# The 240-th cell embedding
# The 241-th cell embedding
# The 242-th cell embedding
# The 243-th cell embedding
# The 244-th cell embedding
# The 245-th cell embedding
# The 246-th cell embedding
# The 247-th cell embedding
# The 248-th cell embedding
# The 249-th cell embedding
# The 250-th cell embedding
# The 251-th cell embedding
# The 252-th cell embedding
# The 253-th cell embedding
# The 254-th cell embedding
# The 255-th cell embedding
# The 256-th cell embedding
# The 257-th cell embedding
# The 258-th cell embedding
# The 259-th cell embedding
# The 260-th cell embedding
# The 261-th cell embedding
# The 262-th cell embedding
# The 263-th cell embedding
# The 264-th cell embedding
# The 265-th cell embedding
# The 266-th cell embedding
# The 267-th cell embedding
# The 268-th cell embedding
# The 269-th cell embedding
# The 270-th cell embedding
# The 271-th cell embedding
# The 272-th cell embedding
# The 273-th cell embedding
# The 274-th cell embedding
# The 275-th cell embedding
# The 276-th cell embedding
# The 277-th cell embedding
# The 278-th cell embedding
# The 279-th cell embedding
# The 280-th cell embedding
# The 281-th cell embedding
# The 282-th cell embedding
# The 283-th cell embedding
# The 284-th cell embedding
# The 285-th cell embedding
# The 286-th cell embedding
# The 287-th cell embedding
# The 288-th cell embedding
# The 289-th cell embedding
# The 290-th cell embedding
# The 291-th cell embedding
# The 292-th cell embedding
# The 293-th cell embedding
# The 294-th cell embedding
# The 295-th cell embedding
# The 296-th cell embedding
# The 297-th cell embedding
# The 298-th cell embedding
# The 299-th cell embedding
# The 300-th cell embedding
# The 301-th cell embedding
# The 302-th cell embedding
# The 303-th cell embedding
# The 304-th cell embedding
# The 305-th cell embedding
# The 306-th cell embedding
# The 307-th cell embedding
# The 308-th cell embedding
# The 309-th cell embedding
# The 310-th cell embedding
# The 311-th cell embedding
# The 312-th cell embedding
# The 313-th cell embedding
# The 314-th cell embedding
# The 315-th cell embedding
# The 316-th cell embedding
# The 317-th cell embedding
# The 318-th cell embedding
# The 319-th cell embedding
# The 320-th cell embedding
# The 321-th cell embedding
# The 322-th cell embedding
# The 323-th cell embedding
# The 324-th cell embedding
# The 325-th cell embedding
# The 326-th cell embedding
# The 327-th cell embedding
# The 328-th cell embedding
# The 329-th cell embedding
# The 330-th cell embedding
# The 331-th cell embedding
# The 332-th cell embedding
# The 333-th cell embedding
# The 334-th cell embedding
# The 335-th cell embedding
# The 336-th cell embedding
# The 337-th cell embedding
# The 338-th cell embedding
# The 339-th cell embedding
# The 340-th cell embedding
# The 341-th cell embedding
# The 342-th cell embedding
# The 343-th cell embedding
# The 344-th cell embedding
# The 345-th cell embedding
# The 346-th cell embedding
# The 347-th cell embedding
# The 348-th cell embedding
# The 349-th cell embedding
# The 350-th cell embedding
# The 351-th cell embedding
# The 352-th cell embedding
# The 353-th cell embedding
# The 354-th cell embedding
# The 355-th cell embedding
# The 356-th cell embedding
# The 357-th cell embedding
# The 358-th cell embedding
# The 359-th cell embedding
# The 360-th cell embedding
# The 361-th cell embedding
# The 362-th cell embedding
# The 363-th cell embedding
# The 364-th cell embedding
# The 365-th cell embedding
# The 366-th cell embedding
# The 367-th cell embedding
# The 368-th cell embedding
# The 369-th cell embedding
# The 370-th cell embedding
# The 371-th cell embedding
# The 372-th cell embedding
# The 373-th cell embedding
# The 374-th cell embedding
# The 375-th cell embedding
# The 376-th cell embedding
# The 377-th cell embedding
# The 378-th cell embedding
# The 379-th cell embedding
# The 380-th cell embedding
# The 381-th cell embedding
# The 382-th cell embedding
# The 383-th cell embedding
# The 384-th cell embedding
# The 385-th cell embedding
# The 386-th cell embedding
# The 387-th cell embedding
# The 388-th cell embedding
# The 389-th cell embedding
# The 390-th cell embedding
# The 391-th cell embedding
# The 392-th cell embedding
# The 393-th cell embedding
# The 394-th cell embedding
# The 395-th cell embedding
# The 396-th cell embedding
# The 397-th cell embedding
# The 398-th cell embedding
# The 399-th cell embedding
# The 400-th cell embedding
# The 401-th cell embedding
# The 402-th cell embedding
# The 403-th cell embedding
# The 404-th cell embedding
# The 405-th cell embedding
# The 406-th cell embedding
# The 407-th cell embedding
# The 408-th cell embedding
# The 409-th cell embedding
# The 410-th cell embedding
# The 411-th cell embedding
# The 412-th cell embedding
# The 413-th cell embedding
# The 414-th cell embedding
# The 415-th cell embedding
# The 416-th cell embedding
# The 417-th cell embedding
# The 418-th cell embedding
# The 419-th cell embedding
# The 420-th cell embedding
# The 421-th cell embedding
# The 422-th cell embedding
# The 423-th cell embedding
# The 424-th cell embedding
# The 425-th cell embedding
# The 426-th cell embedding
# The 427-th cell embedding
# The 428-th cell embedding
# The 429-th cell embedding
# The 430-th cell embedding
# The 431-th cell embedding
# The 432-th cell embedding
# The 433-th cell embedding
# The 434-th cell embedding
# The 435-th cell embedding
# The 436-th cell embedding
# The 437-th cell embedding
# The 438-th cell embedding
# The 439-th cell embedding
# The 440-th cell embedding
# The 441-th cell embedding
# The 442-th cell embedding
# The 443-th cell embedding
# The 444-th cell embedding
# The 445-th cell embedding
# The 446-th cell embedding
# The 447-th cell embedding
# The 448-th cell embedding
# The 449-th cell embedding
# The 450-th cell embedding
# The 451-th cell embedding
# The 452-th cell embedding
# The 453-th cell embedding
# The 454-th cell embedding
# The 455-th cell embedding
# The 456-th cell embedding
# The 457-th cell embedding
# The 458-th cell embedding
# The 459-th cell embedding
# The 460-th cell embedding
# The 461-th cell embedding
# The 462-th cell embedding
# The 463-th cell embedding
# The 464-th cell embedding
# The 465-th cell embedding
# The 466-th cell embedding
# The 467-th cell embedding
# The 468-th cell embedding
# The 469-th cell embedding
# The 470-th cell embedding
# The 471-th cell embedding
# The 472-th cell embedding
# The 473-th cell embedding
# The 474-th cell embedding
# The 475-th cell embedding
# The 476-th cell embedding
# The 477-th cell embedding
# The 478-th cell embedding
# The 479-th cell embedding
# The 480-th cell embedding
# The 481-th cell embedding
# The 482-th cell embedding
# The 483-th cell embedding
# The 484-th cell embedding
# The 485-th cell embedding
# The 486-th cell embedding
# The 487-th cell embedding
# The 488-th cell embedding
# The 489-th cell embedding
# The 490-th cell embedding
# The 491-th cell embedding
# The 492-th cell embedding
# The 493-th cell embedding
# The 494-th cell embedding
# The 495-th cell embedding
# The 496-th cell embedding
# The 497-th cell embedding
# The 498-th cell embedding
# The 499-th cell embedding
# The 500-th cell embedding
# The 501-th cell embedding
# The 502-th cell embedding
# The 503-th cell embedding
# The 504-th cell embedding
# The 505-th cell embedding
# The 506-th cell embedding
# The 507-th cell embedding
# The 508-th cell embedding
# The 509-th cell embedding
# The 510-th cell embedding
# The 511-th cell embedding
# The 512-th cell embedding
# The 513-th cell embedding
# The 514-th cell embedding
# The 515-th cell embedding
# The 516-th cell embedding
# The 517-th cell embedding
# The 518-th cell embedding
# The 519-th cell embedding
# The 520-th cell embedding
# The 521-th cell embedding
# The 522-th cell embedding
# The 523-th cell embedding
# The 524-th cell embedding
# The 525-th cell embedding
# The 526-th cell embedding
# The 527-th cell embedding
# The 528-th cell embedding
# The 529-th cell embedding
# The 530-th cell embedding
# The 531-th cell embedding
# The 532-th cell embedding
# The 533-th cell embedding
# The 534-th cell embedding
# The 535-th cell embedding
# The 536-th cell embedding
# The 537-th cell embedding
# The 538-th cell embedding
# The 539-th cell embedding
# The 540-th cell embedding
# The 541-th cell embedding
# The 542-th cell embedding
# The 543-th cell embedding
# The 544-th cell embedding
# The 545-th cell embedding
# The 546-th cell embedding
# The 547-th cell embedding
# The 548-th cell embedding
# The 549-th cell embedding
# The 550-th cell embedding
# The 551-th cell embedding
# The 552-th cell embedding
# The 553-th cell embedding
# The 554-th cell embedding
# The 555-th cell embedding
# The 556-th cell embedding
# The 557-th cell embedding
# The 558-th cell embedding
# The 559-th cell embedding
# The 560-th cell embedding
# The 561-th cell embedding
# The 562-th cell embedding
# The 563-th cell embedding
# The 564-th cell embedding
# The 565-th cell embedding
# The 566-th cell embedding
# The 567-th cell embedding
# The 568-th cell embedding
# The 569-th cell embedding
# The 570-th cell embedding
# The 571-th cell embedding
# The 572-th cell embedding
# The 573-th cell embedding
# The 574-th cell embedding
# The 575-th cell embedding
# The 576-th cell embedding
# The 577-th cell embedding
# The 578-th cell embedding
# The 579-th cell embedding
# The 580-th cell embedding
# The 581-th cell embedding
# The 582-th cell embedding
# The 583-th cell embedding
# The 584-th cell embedding
# The 585-th cell embedding
# The 586-th cell embedding
# The 587-th cell embedding
# The 588-th cell embedding
# The 589-th cell embedding
# The 590-th cell embedding
# The 591-th cell embedding
# The 592-th cell embedding
# The 593-th cell embedding
# The 594-th cell embedding
# The 595-th cell embedding
# The 596-th cell embedding
# The 597-th cell embedding
# The 598-th cell embedding
# The 599-th cell embedding
# The 600-th cell embedding
# The 601-th cell embedding
# The 602-th cell embedding
# The 603-th cell embedding
# The 604-th cell embedding
# The 605-th cell embedding
# The 606-th cell embedding
# The 607-th cell embedding
# The 608-th cell embedding
# The 609-th cell embedding
# The 610-th cell embedding
# The 611-th cell embedding
# The 612-th cell embedding
# The 613-th cell embedding
# The 614-th cell embedding
# The 615-th cell embedding
# The 616-th cell embedding
# The 617-th cell embedding
# The 618-th cell embedding
# The 619-th cell embedding
# The 620-th cell embedding
# The 621-th cell embedding
# The 622-th cell embedding
# The 623-th cell embedding
# The 624-th cell embedding
# The 625-th cell embedding
# The 626-th cell embedding
# The 627-th cell embedding
# The 628-th cell embedding
# The 629-th cell embedding
# The 630-th cell embedding
# The 631-th cell embedding
# The 632-th cell embedding
# The 633-th cell embedding
# The 634-th cell embedding
# The 635-th cell embedding
# The 636-th cell embedding
# The 637-th cell embedding
# The 638-th cell embedding
# The 639-th cell embedding
# The 640-th cell embedding
# The 641-th cell embedding
# The 642-th cell embedding
# The 643-th cell embedding
# The 644-th cell embedding
# The 645-th cell embedding
# The 646-th cell embedding
# The 647-th cell embedding
# The 648-th cell embedding
# The 649-th cell embedding
# The 650-th cell embedding
# The 651-th cell embedding
# The 652-th cell embedding
# The 653-th cell embedding
# The 654-th cell embedding
# The 655-th cell embedding
# The 656-th cell embedding
# The 657-th cell embedding
# The 658-th cell embedding
# The 659-th cell embedding
# The 660-th cell embedding
# The 661-th cell embedding
# The 662-th cell embedding
# The 663-th cell embedding
# The 664-th cell embedding
# The 665-th cell embedding
# The 666-th cell embedding
# The 667-th cell embedding
# The 668-th cell embedding
# The 669-th cell embedding
# The 670-th cell embedding
# The 671-th cell embedding
# The 672-th cell embedding
# The 673-th cell embedding
# The 674-th cell embedding
# The 675-th cell embedding
# The 676-th cell embedding
# The 677-th cell embedding
# The 678-th cell embedding
# The 679-th cell embedding
# The 680-th cell embedding
# The 681-th cell embedding
# The 682-th cell embedding
# The 683-th cell embedding
# The 684-th cell embedding
# The 685-th cell embedding
# The 686-th cell embedding
# The 687-th cell embedding
# The 688-th cell embedding
# The 689-th cell embedding
# The 690-th cell embedding
# The 691-th cell embedding
# The 692-th cell embedding
# The 693-th cell embedding
# The 694-th cell embedding
# The 695-th cell embedding
# The 696-th cell embedding
# The 697-th cell embedding
# The 698-th cell embedding
# The 699-th cell embedding
# The 700-th cell embedding
# The 701-th cell embedding
# The 702-th cell embedding
# The 703-th cell embedding
# The 704-th cell embedding
# The 705-th cell embedding
# The 706-th cell embedding
# The 707-th cell embedding
# The 708-th cell embedding
# The 709-th cell embedding
# The 710-th cell embedding
# The 711-th cell embedding
# The 712-th cell embedding
# The 713-th cell embedding
# The 714-th cell embedding
# The 715-th cell embedding
# The 716-th cell embedding
# The 717-th cell embedding
# The 718-th cell embedding
# The 719-th cell embedding
# The 720-th cell embedding
# The 721-th cell embedding
# The 722-th cell embedding
# The 723-th cell embedding
# The 724-th cell embedding
# The 725-th cell embedding
# The 726-th cell embedding
# The 727-th cell embedding
# The 728-th cell embedding
# The 729-th cell embedding
# The 730-th cell embedding
# The 731-th cell embedding
# The 732-th cell embedding
# The 733-th cell embedding
# The 734-th cell embedding
# The 735-th cell embedding
# The 736-th cell embedding
# The 737-th cell embedding
# The 738-th cell embedding
# The 739-th cell embedding
# The 740-th cell embedding
# The 741-th cell embedding
# The 742-th cell embedding
# The 743-th cell embedding
# The 744-th cell embedding
# The 745-th cell embedding
# The 746-th cell embedding
# The 747-th cell embedding
# The 748-th cell embedding
# The 749-th cell embedding
# The 750-th cell embedding
# The 751-th cell embedding
# The 752-th cell embedding
# The 753-th cell embedding
# The 754-th cell embedding
# The 755-th cell embedding
# The 756-th cell embedding
# The 757-th cell embedding
# The 758-th cell embedding
# The 759-th cell embedding
# The 760-th cell embedding
# The 761-th cell embedding
# The 762-th cell embedding
# The 763-th cell embedding
# The 764-th cell embedding
# The 765-th cell embedding
# The 766-th cell embedding
# The 767-th cell embedding
# The 768-th cell embedding
# The 769-th cell embedding
# The 770-th cell embedding
# The 771-th cell embedding
# The 772-th cell embedding
# The 773-th cell embedding
# The 774-th cell embedding
# The 775-th cell embedding
# The 776-th cell embedding
# The 777-th cell embedding
# The 778-th cell embedding
# The 779-th cell embedding
# The 780-th cell embedding
# The 781-th cell embedding
# The 782-th cell embedding
# The 783-th cell embedding
# The 784-th cell embedding
# The 785-th cell embedding
# The 786-th cell embedding
# The 787-th cell embedding
# The 788-th cell embedding
# The 789-th cell embedding
# The 790-th cell embedding
# The 791-th cell embedding
# The 792-th cell embedding
# The 793-th cell embedding
# The 794-th cell embedding
# The 795-th cell embedding
# The 796-th cell embedding
# The 797-th cell embedding
# The 798-th cell embedding
# The 799-th cell embedding
# The 800-th cell embedding
# The 801-th cell embedding
# The 802-th cell embedding
# The 803-th cell embedding
# The 804-th cell embedding
# The 805-th cell embedding
# The 806-th cell embedding
# The 807-th cell embedding
# The 808-th cell embedding
# The 809-th cell embedding
# The 810-th cell embedding
# The 811-th cell embedding
# The 812-th cell embedding
# The 813-th cell embedding
# The 814-th cell embedding
# The 815-th cell embedding
# The 816-th cell embedding
# The 817-th cell embedding
# The 818-th cell embedding
# The 819-th cell embedding
# The 820-th cell embedding
# The 821-th cell embedding
# The 822-th cell embedding
# The 823-th cell embedding
# The 824-th cell embedding
# The 825-th cell embedding
# The 826-th cell embedding
# The 827-th cell embedding
# The 828-th cell embedding
# The 829-th cell embedding
# The 830-th cell embedding
# The 831-th cell embedding
# The 832-th cell embedding
# The 833-th cell embedding
# The 834-th cell embedding
# The 835-th cell embedding
# The 836-th cell embedding
# The 837-th cell embedding
# The 838-th cell embedding
# The 839-th cell embedding
# The 840-th cell embedding
# The 841-th cell embedding
# The 842-th cell embedding
# The 843-th cell embedding
# The 844-th cell embedding
# The 845-th cell embedding
# The 846-th cell embedding
# The 847-th cell embedding
# The 848-th cell embedding
# The 849-th cell embedding
# The 850-th cell embedding
# The 851-th cell embedding
# The 852-th cell embedding
# The 853-th cell embedding
# The 854-th cell embedding
# The 855-th cell embedding
# The 856-th cell embedding
# The 857-th cell embedding
# The 858-th cell embedding
# The 859-th cell embedding
# The 860-th cell embedding
# The 861-th cell embedding
# The 862-th cell embedding
# The 863-th cell embedding
# The 864-th cell embedding
# The 865-th cell embedding
# The 866-th cell embedding
# The 867-th cell embedding
# The 868-th cell embedding
# The 869-th cell embedding
# The 870-th cell embedding
# The 871-th cell embedding
# The 872-th cell embedding
# The 873-th cell embedding
# The 874-th cell embedding
# The 875-th cell embedding
# The 876-th cell embedding
# The 877-th cell embedding
# The 878-th cell embedding
# The 879-th cell embedding
# The 880-th cell embedding
# The 881-th cell embedding
# The 882-th cell embedding
# The 883-th cell embedding
# The 884-th cell embedding
# The 885-th cell embedding
# The 886-th cell embedding
# The 887-th cell embedding
# The 888-th cell embedding
# The 889-th cell embedding
# The 890-th cell embedding
# The 891-th cell embedding
# The 892-th cell embedding
# The 893-th cell embedding
# The 894-th cell embedding
# The 895-th cell embedding
# The 896-th cell embedding
# The 897-th cell embedding
# The 898-th cell embedding
# The 899-th cell embedding
# The 900-th cell embedding
# The 901-th cell embedding
# The 902-th cell embedding
# The 903-th cell embedding
# The 904-th cell embedding
# The 905-th cell embedding
# The 906-th cell embedding
# The 907-th cell embedding
# The 908-th cell embedding
# The 909-th cell embedding
# The 910-th cell embedding
# The 911-th cell embedding
# The 912-th cell embedding
# The 913-th cell embedding
# The 914-th cell embedding
# The 915-th cell embedding
# The 916-th cell embedding
# The 917-th cell embedding
# The 918-th cell embedding
# The 919-th cell embedding
# The 920-th cell embedding
# The 921-th cell embedding
# The 922-th cell embedding
# The 923-th cell embedding
# The 924-th cell embedding
# The 925-th cell embedding
# The 926-th cell embedding
# The 927-th cell embedding
# The 928-th cell embedding
# The 929-th cell embedding
# The 930-th cell embedding
# The 931-th cell embedding
# The 932-th cell embedding
# The 933-th cell embedding
# The 934-th cell embedding
# The 935-th cell embedding
# The 936-th cell embedding
# The 937-th cell embedding
# The 938-th cell embedding
# The 939-th cell embedding
# The 940-th cell embedding
# The 941-th cell embedding
# The 942-th cell embedding
# The 943-th cell embedding
# The 944-th cell embedding
# The 945-th cell embedding
# The 946-th cell embedding
# The 947-th cell embedding
# The 948-th cell embedding
# The 949-th cell embedding
# The 950-th cell embedding
# The 951-th cell embedding
# The 952-th cell embedding
# The 953-th cell embedding
# The 954-th cell embedding
# The 955-th cell embedding
# The 956-th cell embedding
# The 957-th cell embedding
# The 958-th cell embedding
# The 959-th cell embedding
# The 960-th cell embedding
# The 961-th cell embedding
# The 962-th cell embedding
# The 963-th cell embedding
# The 964-th cell embedding
# The 965-th cell embedding
# The 966-th cell embedding
# The 967-th cell embedding
# The 968-th cell embedding
# The 969-th cell embedding
# The 970-th cell embedding
# The 971-th cell embedding
# The 972-th cell embedding
# The 973-th cell embedding
# The 974-th cell embedding
# The 975-th cell embedding
# The 976-th cell embedding
# The 977-th cell embedding
# The 978-th cell embedding
# The 979-th cell embedding
# The 980-th cell embedding
# The 981-th cell embedding
# The 982-th cell embedding
# The 983-th cell embedding
# The 984-th cell embedding
# The 985-th cell embedding
# The 986-th cell embedding
# The 987-th cell embedding
# The 988-th cell embedding
# The 989-th cell embedding
# The 990-th cell embedding
# The 991-th cell embedding
# The 992-th cell embedding
# The 993-th cell embedding
# The 994-th cell embedding
# The 995-th cell embedding
# The 996-th cell embedding
# The 997-th cell embedding
# The 998-th cell embedding
# The 999-th cell embedding
# The 1000-th cell embedding
# The 1001-th cell embedding
# The 1002-th cell embedding
# The 1003-th cell embedding
# The 1004-th cell embedding
# The 1005-th cell embedding
# The 1006-th cell embedding
# The 1007-th cell embedding
# The 1008-th cell embedding
# The 1009-th cell embedding
# The 1010-th cell embedding
# The 1011-th cell embedding
# The 1012-th cell embedding
# The 1013-th cell embedding
# The 1014-th cell embedding
# The 1015-th cell embedding
# The 1016-th cell embedding
# The 1017-th cell embedding
# The 1018-th cell embedding
# The 1019-th cell embedding
# The 1020-th cell embedding
# The 1021-th cell embedding
# The 1022-th cell embedding
# The 1023-th cell embedding
# The 1024-th cell embedding
# The 1025-th cell embedding
# The 1026-th cell embedding
# The 1027-th cell embedding
# The 1028-th cell embedding
# The 1029-th cell embedding
# The 1030-th cell embedding
# The 1031-th cell embedding
# The 1032-th cell embedding
# The 1033-th cell embedding
# The 1034-th cell embedding
# The 1035-th cell embedding
# The 1036-th cell embedding
# The 1037-th cell embedding
# The 1038-th cell embedding
# The 1039-th cell embedding
# The 1040-th cell embedding
# The 1041-th cell embedding
# The 1042-th cell embedding
# The 1043-th cell embedding
# The 1044-th cell embedding
# The 1045-th cell embedding
# The 1046-th cell embedding
# The 1047-th cell embedding
# The 1048-th cell embedding
# The 1049-th cell embedding
# The 1050-th cell embedding
# The 1051-th cell embedding
# The 1052-th cell embedding
# The 1053-th cell embedding
# The 1054-th cell embedding
# The 1055-th cell embedding
# The 1056-th cell embedding
# The 1057-th cell embedding
# The 1058-th cell embedding
# The 1059-th cell embedding
# The 1060-th cell embedding
# The 1061-th cell embedding
# The 1062-th cell embedding
# The 1063-th cell embedding
# The 1064-th cell embedding
# The 1065-th cell embedding
# The 1066-th cell embedding
# The 1067-th cell embedding
# The 1068-th cell embedding
# The 1069-th cell embedding
# The 1070-th cell embedding
# The 1071-th cell embedding
# The 1072-th cell embedding
# The 1073-th cell embedding
# The 1074-th cell embedding
# The 1075-th cell embedding
# The 1076-th cell embedding
# The 1077-th cell embedding
# The 1078-th cell embedding
# The 1079-th cell embedding
# The 1080-th cell embedding
# The 1081-th cell embedding
# The 1082-th cell embedding
# The 1083-th cell embedding
# The 1084-th cell embedding
# The 1085-th cell embedding
# The 1086-th cell embedding
# The 1087-th cell embedding
# The 1088-th cell embedding
# The 1089-th cell embedding
# The 1090-th cell embedding
# The 1091-th cell embedding
# The 1092-th cell embedding
# The 1093-th cell embedding
# The 1094-th cell embedding
# The 1095-th cell embedding
# The 1096-th cell embedding
# The 1097-th cell embedding
# The 1098-th cell embedding
# The 1099-th cell embedding
# The 1100-th cell embedding
# The 1101-th cell embedding
# The 1102-th cell embedding
# The 1103-th cell embedding
# The 1104-th cell embedding
# The 1105-th cell embedding
# The 1106-th cell embedding
# The 1107-th cell embedding
# The 1108-th cell embedding
# The 1109-th cell embedding
# The 1110-th cell embedding
# The 1111-th cell embedding
# The 1112-th cell embedding
# The 1113-th cell embedding
# The 1114-th cell embedding
# The 1115-th cell embedding
# The 1116-th cell embedding
# The 1117-th cell embedding
# The 1118-th cell embedding
# The 1119-th cell embedding
# The 1120-th cell embedding
# The 1121-th cell embedding
# The 1122-th cell embedding
# The 1123-th cell embedding
# The 1124-th cell embedding
# The 1125-th cell embedding
# The 1126-th cell embedding
# The 1127-th cell embedding
# The 1128-th cell embedding
# The 1129-th cell embedding
# The 1130-th cell embedding
# The 1131-th cell embedding
# The 1132-th cell embedding
# The 1133-th cell embedding
# The 1134-th cell embedding
# The 1135-th cell embedding
# The 1136-th cell embedding
# The 1137-th cell embedding
# The 1138-th cell embedding
# The 1139-th cell embedding
# The 1140-th cell embedding
# The 1141-th cell embedding
# The 1142-th cell embedding
# The 1143-th cell embedding
# The 1144-th cell embedding
# The 1145-th cell embedding
# The 1146-th cell embedding
# The 1147-th cell embedding
# The 1148-th cell embedding
# The 1149-th cell embedding
# The 1150-th cell embedding
# The 1151-th cell embedding
# The 1152-th cell embedding
# The 1153-th cell embedding
# The 1154-th cell embedding
# The 1155-th cell embedding
# The 1156-th cell embedding
# The 1157-th cell embedding
# The 1158-th cell embedding
# The 1159-th cell embedding
# The 1160-th cell embedding
# The 1161-th cell embedding
# The 1162-th cell embedding
# The 1163-th cell embedding
# The 1164-th cell embedding
# The 1165-th cell embedding
# The 1166-th cell embedding
# The 1167-th cell embedding
# The 1168-th cell embedding
# The 1169-th cell embedding
# The 1170-th cell embedding
# The 1171-th cell embedding
# The 1172-th cell embedding
# The 1173-th cell embedding
# The 1174-th cell embedding
# The 1175-th cell embedding
# The 1176-th cell embedding
# The 1177-th cell embedding
# The 1178-th cell embedding
# The 1179-th cell embedding
# The 1180-th cell embedding
# The 1181-th cell embedding
# The 1182-th cell embedding
# The 1183-th cell embedding
# The 1184-th cell embedding
# The 1185-th cell embedding
# The 1186-th cell embedding
# The 1187-th cell embedding
# The 1188-th cell embedding
# The 1189-th cell embedding
# The 1190-th cell embedding
# The 1191-th cell embedding
# The 1192-th cell embedding
# The 1193-th cell embedding
# The 1194-th cell embedding
# The 1195-th cell embedding
# The 1196-th cell embedding
# The 1197-th cell embedding
# The 1198-th cell embedding
# The 1199-th cell embedding
# The 1200-th cell embedding
# The 1201-th cell embedding
# The 1202-th cell embedding
# The 1203-th cell embedding
# The 1204-th cell embedding
# The 1205-th cell embedding
# The 1206-th cell embedding
# The 1207-th cell embedding
# The 1208-th cell embedding
# The 1209-th cell embedding
# The 1210-th cell embedding
# The 1211-th cell embedding
# The 1212-th cell embedding
# The 1213-th cell embedding
# The 1214-th cell embedding
# The 1215-th cell embedding
# The 1216-th cell embedding
# The 1217-th cell embedding
# The 1218-th cell embedding
# The 1219-th cell embedding
# The 1220-th cell embedding
# The 1221-th cell embedding
# The 1222-th cell embedding
# The 1223-th cell embedding
# The 1224-th cell embedding
# The 1225-th cell embedding
# The 1226-th cell embedding
# The 1227-th cell embedding
# The 1228-th cell embedding
# The 1229-th cell embedding
# The 1230-th cell embedding
# The 1231-th cell embedding
# The 1232-th cell embedding
# The 1233-th cell embedding
# The 1234-th cell embedding
# The 1235-th cell embedding
# The 1236-th cell embedding
# The 1237-th cell embedding
# The 1238-th cell embedding
# The 1239-th cell embedding
# The 1240-th cell embedding
# The 1241-th cell embedding
# The 1242-th cell embedding
# The 1243-th cell embedding
# The 1244-th cell embedding
# The 1245-th cell embedding
# The 1246-th cell embedding
# The 1247-th cell embedding
# The 1248-th cell embedding
# The 1249-th cell embedding
# The 1250-th cell embedding
# The 1251-th cell embedding
# The 1252-th cell embedding
# The 1253-th cell embedding
# The 1254-th cell embedding
# The 1255-th cell embedding
# The 1256-th cell embedding
# The 1257-th cell embedding
# The 1258-th cell embedding
# The 1259-th cell embedding
# The 1260-th cell embedding
# The 1261-th cell embedding
# The 1262-th cell embedding
# The 1263-th cell embedding
# The 1264-th cell embedding
# The 1265-th cell embedding
# The 1266-th cell embedding
# The 1267-th cell embedding
# The 1268-th cell embedding
# The 1269-th cell embedding
# The 1270-th cell embedding
# The 1271-th cell embedding
# The 1272-th cell embedding
# The 1273-th cell embedding
# The 1274-th cell embedding
# The 1275-th cell embedding
# The 1276-th cell embedding
# The 1277-th cell embedding
# The 1278-th cell embedding
# The 1279-th cell embedding
# The 1280-th cell embedding
# The 1281-th cell embedding
# The 1282-th cell embedding
# The 1283-th cell embedding
# The 1284-th cell embedding
# The 1285-th cell embedding
# The 1286-th cell embedding
# The 1287-th cell embedding
# The 1288-th cell embedding
# The 1289-th cell embedding
# The 1290-th cell embedding
# The 1291-th cell embedding
# The 1292-th cell embedding
# The 1293-th cell embedding
# The 1294-th cell embedding
# The 1295-th cell embedding
# The 1296-th cell embedding
# The 1297-th cell embedding
# The 1298-th cell embedding
# The 1299-th cell embedding
# The 1300-th cell embedding
# The 1301-th cell embedding
# The 1302-th cell embedding
# The 1303-th cell embedding
# The 1304-th cell embedding
# The 1305-th cell embedding
# The 1306-th cell embedding
# The 1307-th cell embedding
# The 1308-th cell embedding
# The 1309-th cell embedding
# The 1310-th cell embedding
# The 1311-th cell embedding
# The 1312-th cell embedding
# The 1313-th cell embedding
# The 1314-th cell embedding
# The 1315-th cell embedding
# The 1316-th cell embedding
# The 1317-th cell embedding
# The 1318-th cell embedding
# The 1319-th cell embedding
# The 1320-th cell embedding
# The 1321-th cell embedding
# The 1322-th cell embedding
# The 1323-th cell embedding
# The 1324-th cell embedding
# The 1325-th cell embedding
# The 1326-th cell embedding
# The 1327-th cell embedding
# The 1328-th cell embedding
# The 1329-th cell embedding
# The 1330-th cell embedding
# The 1331-th cell embedding
# The 1332-th cell embedding
# The 1333-th cell embedding
# The 1334-th cell embedding
# The 1335-th cell embedding
# The 1336-th cell embedding
# The 1337-th cell embedding
# The 1338-th cell embedding
# The 1339-th cell embedding
# The 1340-th cell embedding
# The 1341-th cell embedding
# The 1342-th cell embedding
# The 1343-th cell embedding
# The 1344-th cell embedding
# The 1345-th cell embedding
# The 1346-th cell embedding
# The 1347-th cell embedding
# The 1348-th cell embedding
# The 1349-th cell embedding
# The 1350-th cell embedding
# The 1351-th cell embedding
# The 1352-th cell embedding
# The 1353-th cell embedding
# The 1354-th cell embedding
# The 1355-th cell embedding
# The 1356-th cell embedding
# The 1357-th cell embedding
# The 1358-th cell embedding
# The 1359-th cell embedding
# The 1360-th cell embedding
# The 1361-th cell embedding
# The 1362-th cell embedding
# The 1363-th cell embedding
# The 1364-th cell embedding
# ...
# The 2436-th cell embedding
# The 2437-th cell embedding
# The 2438-th cell embedding
# The 2439-th cell embedding
# The 2440-th cell embedding
# The 2441-th cell embedding
# The 2442-th cell embedding
# The 2443-th cell embedding
# The 2444-th cell embedding
# The 2445-th cell embedding
# The 2446-th cell embedding
# The 2447-th cell embedding
# The 2448-th cell embedding
# The 2449-th cell embedding
# The 2450-th cell embedding
# The 2451-th cell embedding
# The 2452-th cell embedding
# The 2453-th cell embedding
# The 2454-th cell embedding
# The 2455-th cell embedding
# The 2456-th cell embedding
# The 2457-th cell embedding
# The 2458-th cell embedding
# The 2459-th cell embedding
# The 2460-th cell embedding
# The 2461-th cell embedding
# The 2462-th cell embedding
# The 2463-th cell embedding
# The 2464-th cell embedding
# The 2465-th cell embedding
# The 2466-th cell embedding
# The 2467-th cell embedding
# The 2468-th cell embedding
# The 2469-th cell embedding
# The 2470-th cell embedding
# The 2471-th cell embedding
# The 2472-th cell embedding
# The 2473-th cell embedding
# The 2474-th cell embedding
# The 2475-th cell embedding
# The 2476-th cell embedding
# The 2477-th cell embedding
# The 2478-th cell embedding
# The 2479-th cell embedding
# The 2480-th cell embedding
# The 2481-th cell embedding
# The 2482-th cell embedding
# The 2483-th cell embedding
# The 2484-th cell embedding
# The 2485-th cell embedding
# The 2486-th cell embedding
# The 2487-th cell embedding
# The 2488-th cell embedding
# The 2489-th cell embedding
# The 2490-th cell embedding
# The 2491-th cell embedding
# The 2492-th cell embedding
# The 2493-th cell embedding
# The 2494-th cell embedding
# The 2495-th cell embedding
# The 2496-th cell embedding
# The 2497-th cell embedding
# The 2498-th cell embedding
# The 2499-th cell embedding
# The 2500-th cell embedding
# The 2501-th cell embedding
# The 2502-th cell embedding
# The 2503-th cell embedding
# The 2504-th cell embedding
# The 2505-th cell embedding
# The 2506-th cell embedding
# The 2507-th cell embedding
# The 2508-th cell embedding
# The 2509-th cell embedding
# The 2510-th cell embedding
# The 2511-th cell embedding
# The 2512-th cell embedding
# The 2513-th cell embedding
# The 2514-th cell embedding
# The 2515-th cell embedding
# The 2516-th cell embedding
# The 2517-th cell embedding
# The 2518-th cell embedding
# The 2519-th cell embedding
# The 2520-th cell embedding
# The 2521-th cell embedding
# The 2522-th cell embedding
# The 2523-th cell embedding
# The 2524-th cell embedding
# The 2525-th cell embedding
# The 2526-th cell embedding
# The 2527-th cell embedding
# The 2528-th cell embedding
# The 2529-th cell embedding
# The 2530-th cell embedding
# The 2531-th cell embedding
# The 2532-th cell embedding
# The 2533-th cell embedding
# The 2534-th cell embedding
# The 2535-th cell embedding
# The 2536-th cell embedding
# The 2537-th cell embedding
# The 2538-th cell embedding
# The 2539-th cell embedding
# The 2540-th cell embedding
# The 2541-th cell embedding
# The 2542-th cell embedding
# The 2543-th cell embedding
# The 2544-th cell embedding
# The 2545-th cell embedding
# The 2546-th cell embedding
# The 2547-th cell embedding
# The 2548-th cell embedding
# The 2549-th cell embedding
# The 2550-th cell embedding
# The 2551-th cell embedding
# The 2552-th cell embedding
# The 2553-th cell embedding
# The 2554-th cell embedding
# The 2555-th cell embedding
# The 2556-th cell embedding
# The 2557-th cell embedding
# The 2558-th cell embedding
# The 2559-th cell embedding
# The 2560-th cell embedding
# The 2561-th cell embedding
# The 2562-th cell embedding
# The 2563-th cell embedding
# The 2564-th cell embedding
# The 2565-th cell embedding
# The 2566-th cell embedding
# The 2567-th cell embedding
# The 2568-th cell embedding
# The 2569-th cell embedding
# The 2570-th cell embedding
# The 2571-th cell embedding
# The 2572-th cell embedding
# The 2573-th cell embedding
# The 2574-th cell embedding
# The 2575-th cell embedding
# The 2576-th cell embedding
# The 2577-th cell embedding
# The 2578-th cell embedding
# The 2579-th cell embedding
# The 2580-th cell embedding
# The 2581-th cell embedding
# The 2582-th cell embedding
# The 2583-th cell embedding
# The 2584-th cell embedding
# The 2585-th cell embedding
# The 2586-th cell embedding
# The 2587-th cell embedding
# The 2588-th cell embedding
# The 2589-th cell embedding
# The 2590-th cell embedding
# The 2591-th cell embedding
# The 2592-th cell embedding
# The 2593-th cell embedding
# The 2594-th cell embedding
# The 2595-th cell embedding
# The 2596-th cell embedding
# The 2597-th cell embedding
# The 2598-th cell embedding
# The 2599-th cell embedding
# The 2600-th cell embedding
# The 2601-th cell embedding
# The 2602-th cell embedding
# The 2603-th cell embedding
# The 2604-th cell embedding
# The 2605-th cell embedding
# The 2606-th cell embedding
# The 2607-th cell embedding
# The 2608-th cell embedding
# The 2609-th cell embedding
# The 2610-th cell embedding
# The 2611-th cell embedding
# The 2612-th cell embedding
# The 2613-th cell embedding
# The 2614-th cell embedding
# The 2615-th cell embedding
# The 2616-th cell embedding
# The 2617-th cell embedding
# The 2618-th cell embedding
# The 2619-th cell embedding
# The 2620-th cell embedding
# The 2621-th cell embedding
# The 2622-th cell embedding
# The 2623-th cell embedding
# The 2624-th cell embedding
# The 2625-th cell embedding
# The 2626-th cell embedding
# The 2627-th cell embedding
# The 2628-th cell embedding
# The 2629-th cell embedding
# The 2630-th cell embedding
# The 2631-th cell embedding
# The 2632-th cell embedding
# The 2633-th cell embedding
# The 2634-th cell embedding
# The 2635-th cell embedding
# The 2636-th cell embedding
# The 2637-th cell embedding
# The 2638-th cell embedding
# The 2639-th cell embedding
# The 2640-th cell embedding
# The 2641-th cell embedding
# The 2642-th cell embedding
# The 2643-th cell embedding
# The 2644-th cell embedding
# The 2645-th cell embedding
# The 2646-th cell embedding
# The 2647-th cell embedding
# The 2648-th cell embedding
# The 2649-th cell embedding
# The 2650-th cell embedding
# The 2651-th cell embedding
# The 2652-th cell embedding
# The 2653-th cell embedding
# The 2654-th cell embedding
# The 2655-th cell embedding
# The 2656-th cell embedding
# The 2657-th cell embedding
# The 2658-th cell embedding
# The 2659-th cell embedding
# The 2660-th cell embedding
# The 2661-th cell embedding
# The 2662-th cell embedding
# The 2663-th cell embedding
# The 2664-th cell embedding
# The 2665-th cell embedding
# The 2666-th cell embedding
# The 2667-th cell embedding
# The 2668-th cell embedding
# The 2669-th cell embedding
# The 2670-th cell embedding
# The 2671-th cell embedding
# The 2672-th cell embedding
# The 2673-th cell embedding
# The 2674-th cell embedding
# The 2675-th cell embedding
# The 2676-th cell embedding
# The 2677-th cell embedding
# The 2678-th cell embedding
# The 2679-th cell embedding
# The 2680-th cell embedding
# The 2681-th cell embedding
# The 2682-th cell embedding
# The 2683-th cell embedding
# The 2684-th cell embedding
# The 2685-th cell embedding
# The 2686-th cell embedding
# The 2687-th cell embedding
# The 2688-th cell embedding
# The 2689-th cell embedding
# The 2690-th cell embedding
# The 2691-th cell embedding
# The 2692-th cell embedding
# The 2693-th cell embedding
# The 2694-th cell embedding
# The 2695-th cell embedding
# The 2696-th cell embedding
# The 2697-th cell embedding
# The 2698-th cell embedding
# The 2699-th cell embedding
# The 2700-th cell embedding
# The 2701-th cell embedding
# The 2702-th cell embedding
# The 2703-th cell embedding
# The 2704-th cell embedding
# The 2705-th cell embedding
# The 2706-th cell embedding
# The 2707-th cell embedding
# The 2708-th cell embedding
# The 2709-th cell embedding
# The 2710-th cell embedding
# The 2711-th cell embedding
# The 2712-th cell embedding
# The 2713-th cell embedding
# The 2714-th cell embedding
# The 2715-th cell embedding
# The 2716-th cell embedding
# The 2717-th cell embedding
# The 2718-th cell embedding
# The 2719-th cell embedding
# The 2720-th cell embedding
# The 2721-th cell embedding
# The 2722-th cell embedding
# The 2723-th cell embedding
# The 2724-th cell embedding
# The 2725-th cell embedding
# The 2726-th cell embedding
# The 2727-th cell embedding
# The 2728-th cell embedding
# The 2729-th cell embedding
# The 2730-th cell embedding
# The 2731-th cell embedding
# The 2732-th cell embedding
# The 2733-th cell embedding
# The 2734-th cell embedding
# The 2735-th cell embedding
# The 2736-th cell embedding
# The 2737-th cell embedding
# The 2738-th cell embedding
# The 2739-th cell embedding
# The 2740-th cell embedding
# The 2741-th cell embedding
# The 2742-th cell embedding
# The 2743-th cell embedding
# The 2744-th cell embedding
# The 2745-th cell embedding
# The 2746-th cell embedding
# The 2747-th cell embedding
# The 2748-th cell embedding
# The 2749-th cell embedding
# The 2750-th cell embedding
# The 2751-th cell embedding
# The 2752-th cell embedding
# The 2753-th cell embedding
# The 2754-th cell embedding
# The 2755-th cell embedding
# The 2756-th cell embedding
# The 2757-th cell embedding
# The 2758-th cell embedding
# The 2759-th cell embedding
# The 2760-th cell embedding
# The 2761-th cell embedding
# The 2762-th cell embedding
# The 2763-th cell embedding
# The 2764-th cell embedding
# The 2765-th cell embedding
# The 2766-th cell embedding
# The 2767-th cell embedding
# The 2768-th cell embedding
# The 2769-th cell embedding
# The 2770-th cell embedding
# The 2771-th cell embedding
# The 2772-th cell embedding
# The 2773-th cell embedding
# The 2774-th cell embedding
# The 2775-th cell embedding
# The 2776-th cell embedding
# The 2777-th cell embedding
# The 2778-th cell embedding
# The 2779-th cell embedding
# The 2780-th cell embedding
# The 2781-th cell embedding
# The 2782-th cell embedding
# The 2783-th cell embedding
# The 2784-th cell embedding
# The 2785-th cell embedding
# The 2786-th cell embedding
# The 2787-th cell embedding
# The 2788-th cell embedding
# The 2789-th cell embedding
# The 2790-th cell embedding
# The 2791-th cell embedding
# The 2792-th cell embedding
# The 2793-th cell embedding
# The 2794-th cell embedding
# The 2795-th cell embedding
# The 2796-th cell embedding
# The 2797-th cell embedding
# The 2798-th cell embedding
# The 2799-th cell embedding
# The 2800-th cell embedding
# The 2801-th cell embedding
# The 2802-th cell embedding
# The 2803-th cell embedding
# The 2804-th cell embedding
# The 2805-th cell embedding
# The 2806-th cell embedding
# The 2807-th cell embedding
# The 2808-th cell embedding
# The 2809-th cell embedding
# The 2810-th cell embedding
# The 2811-th cell embedding
# The 2812-th cell embedding
# The 2813-th cell embedding
# The 2814-th cell embedding
# The 2815-th cell embedding
# The 2816-th cell embedding
# The 2817-th cell embedding
# The 2818-th cell embedding
# The 2819-th cell embedding
# The 2820-th cell embedding
# The 2821-th cell embedding
# The 2822-th cell embedding
# The 2823-th cell embedding
# The 2824-th cell embedding
# The 2825-th cell embedding
# The 2826-th cell embedding
# The 2827-th cell embedding
# The 2828-th cell embedding
# The 2829-th cell embedding
# The 2830-th cell embedding
# The 2831-th cell embedding
# The 2832-th cell embedding
# The 2833-th cell embedding
# The 2834-th cell embedding
# The 2835-th cell embedding
# The 2836-th cell embedding
# The 2837-th cell embedding
# The 2838-th cell embedding
# The 2839-th cell embedding
# The 2840-th cell embedding
# The 2841-th cell embedding
# The 2842-th cell embedding
# The 2843-th cell embedding
# The 2844-th cell embedding
# The 2845-th cell embedding
# The 2846-th cell embedding
# The 2847-th cell embedding
# The 2848-th cell embedding
# The 2849-th cell embedding
# The 2850-th cell embedding
# The 2851-th cell embedding
# The 2852-th cell embedding
# The 2853-th cell embedding
# The 2854-th cell embedding
# The 2855-th cell embedding
# The 2856-th cell embedding
# The 2857-th cell embedding
# The 2858-th cell embedding
# The 2859-th cell embedding
# The 2860-th cell embedding
# The 2861-th cell embedding
# The 2862-th cell embedding
# The 2863-th cell embedding
# The 2864-th cell embedding
# The 2865-th cell embedding
# The 2866-th cell embedding
# The 2867-th cell embedding
# The 2868-th cell embedding
# The 2869-th cell embedding
# The 2870-th cell embedding
# The 2871-th cell embedding
# The 2872-th cell embedding
# The 2873-th cell embedding
# The 2874-th cell embedding
# The 2875-th cell embedding
# The 2876-th cell embedding
# The 2877-th cell embedding
# The 2878-th cell embedding
# The 2879-th cell embedding
# The 2880-th cell embedding
# The 2881-th cell embedding
# The 2882-th cell embedding
# The 2883-th cell embedding
# The 2884-th cell embedding
# The 2885-th cell embedding
# The 2886-th cell embedding
# The 2887-th cell embedding
# The 2888-th cell embedding
# The 2889-th cell embedding
# The 2890-th cell embedding
# The 2891-th cell embedding
# The 2892-th cell embedding
# The 2893-th cell embedding
# The 2894-th cell embedding
# The 2895-th cell embedding
# The 2896-th cell embedding
# The 2897-th cell embedding
# The 2898-th cell embedding
# The 2899-th cell embedding
# The 2900-th cell embedding
# The 2901-th cell embedding
# The 2902-th cell embedding
# The 2903-th cell embedding
# The 2904-th cell embedding
# The 2905-th cell embedding
# The 2906-th cell embedding
# The 2907-th cell embedding
# The 2908-th cell embedding
# The 2909-th cell embedding
# The 2910-th cell embedding
# The 2911-th cell embedding
# The 2912-th cell embedding
# The 2913-th cell embedding
# The 2914-th cell embedding
# The 2915-th cell embedding
# The 2916-th cell embedding
# The 2917-th cell embedding
# The 2918-th cell embedding
# The 2919-th cell embedding
# The 2920-th cell embedding
# The 2921-th cell embedding
# The 2922-th cell embedding
# The 2923-th cell embedding
# The 2924-th cell embedding
# The 2925-th cell embedding
# The 2926-th cell embedding
# The 2927-th cell embedding
# The 2928-th cell embedding
# The 2929-th cell embedding
# The 2930-th cell embedding
# The 2931-th cell embedding
# The 2932-th cell embedding
# The 2933-th cell embedding
# The 2934-th cell embedding
# The 2935-th cell embedding
# The 2936-th cell embedding
# The 2937-th cell embedding
# The 2938-th cell embedding
# The 2939-th cell embedding
# The 2940-th cell embedding
# The 2941-th cell embedding
# The 2942-th cell embedding
# The 2943-th cell embedding
# The 2944-th cell embedding
# The 2945-th cell embedding
# The 2946-th cell embedding
# The 2947-th cell embedding
# The 2948-th cell embedding
# The 2949-th cell embedding
# The 2950-th cell embedding
# The 2951-th cell embedding
# The 2952-th cell embedding
# The 2953-th cell embedding
# The 2954-th cell embedding
# The 2955-th cell embedding
# The 2956-th cell embedding
# The 2957-th cell embedding
# The 2958-th cell embedding
# The 2959-th cell embedding
# The 2960-th cell embedding
# The 2961-th cell embedding
# The 2962-th cell embedding
# The 2963-th cell embedding
# The 2964-th cell embedding
# The 2965-th cell embedding
# The 2966-th cell embedding
# The 2967-th cell embedding
# The 2968-th cell embedding
# The 2969-th cell embedding
# The 2970-th cell embedding
# The 2971-th cell embedding
# The 2972-th cell embedding
# The 2973-th cell embedding
# The 2974-th cell embedding
# The 2975-th cell embedding
# The 2976-th cell embedding
# The 2977-th cell embedding
# The 2978-th cell embedding
# The 2979-th cell embedding
# The 2980-th cell embedding
# The 2981-th cell embedding
# The 2982-th cell embedding
# The 2983-th cell embedding
# The 2984-th cell embedding
# The 2985-th cell embedding
# The 2986-th cell embedding
# The 2987-th cell embedding
# The 2988-th cell embedding
# The 2989-th cell embedding
# The 2990-th cell embedding
# The 2991-th cell embedding
# The 2992-th cell embedding
# The 2993-th cell embedding
# The 2994-th cell embedding
# The 2995-th cell embedding
# The 2996-th cell embedding
# The 2997-th cell embedding
# The 2998-th cell embedding
# Cross Fusion complete.
#            feature1  feature2  feature3  feature4  feature5  feature6  \
# Accuracy   0.960309  0.979320  0.975985  0.974650  0.982990  0.758835
# Precision  0.962588  0.979444  0.976576  0.974951  0.983186  0.761053
# Recall     0.960309  0.979320  0.975985  0.974650  0.982990  0.758835
# F1         0.960076  0.979313  0.975896  0.974613  0.982959  0.753840
# MCC        0.949851  0.973477  0.969405  0.967539  0.978250  0.689785
#
#            feature7  feature8  feature9  feature10
# Accuracy   0.955302  0.980322  0.977319   0.979654
# Precision  0.956969  0.980684  0.977808   0.979905
# Recall     0.955302  0.980322  0.977319   0.979654
# F1         0.955218  0.980296  0.977275   0.979609
# MCC        0.943005  0.974869  0.971040   0.973980

# %% [markdown]
# ### Feature Embedding Files and Their Dimensions
#
# | Feature ID | File Name                                                               | Dimension      |
# |------------|-------------------------------------------------------------------------|----------------|
# | Feature0   | expr.csv                                                                | (33694, 2998)  |
# | Feature1   | expr_2000.csv                                                           | (2000, 2998)   |
# | Feature2   | scPSD_embedding.txt.gz                                                  | (2998, 2000)   |
# | Feature3   | PCA_embedding.txt.gz                                                    | (2998, 266)    |
# | Feature4   | scGNN_embedding.csv                                                     | (2998, 129)    |
# | Feature5   | Fusion_sum-expr-scpsd-scgnn-pca.txt.gz                                  | (2998, 2000)   |
# | Feature6   | Fusion_hadamard-expr-scpsd-scgnn-pca.txt.gz                             | (2998, 2000)   |
# | Feature7   | Fusion_attention-expr-scpsd-scgnn-pca.txt.gz                            | (2998, 2000)   |
# | Feature8   | Fusion_moe-expr-scpsd-scgnn-pca.txt.gz                                  | (2998, 128)    |
# | Feature9   | Fusion_residual-expr-scpsd-scgnn-pca.txt.gz                             | (2998, 128)    |
# | Feature10  | Fusion_transformer-expr-scpsd-scgnn-pca.txt.gz                          | (2998, 128)    |

# %% [markdown]
# # Step-by-step testing scMFF_pipeline.py

# %%
pwd
# Out:
# '/mnt/202001Main/BioData/Transcriptome_classification/scMFF/scMFF'

# %%
ls
# Out:
# Classifier.py           Model.png         README.md          utils.py
# Example_data/           Preprocessing.py  scGNN/
# Example_data_complete/  psdPy/            scMFF_pipeline.py
# Fusion.py               __pycache__/      test.ipynb

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from Preprocessing import *
from Fusion import *
from Classifier import *
from utils import *

import sys  
import os
from sklearn.decomposition import PCA

# %%
dir = 'Example_data/'
model_name = 'KNN'

# %%
print('---------------------------------------------------------------')
print('Step 0: Data loading in progress...')
df = pd.read_csv(dir + 'expr.csv', index_col=0, header=0)

CellType = pd.read_csv(dir + 'cluster.csv', header=None).iloc[:, 0].values
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(CellType)
num_classes = len(np.unique(Y))

print('Data loading complete.')
# Out:
# ---------------------------------------------------------------
# Step 0: Data loading in progress...
# Data loading complete.

# %%
####        Step 1: Data Pre-processing          ########################################################
print('---------------------------------------------------------------')
print('Step 1: Data preprocessing in progress...')
df0 = preprocess_RNASeq(df)
df0.to_csv(dir + 'expr_2000.csv')
print('Data preprocessing complete.')
# Out:
# ---------------------------------------------------------------
# Step 1: Data preprocessing in progress...
# /home/sunnan/anaconda3/envs/SunNan_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1113: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /mnt/202001Main/BioData/Transcriptome_classification/scMFF/scMFF/Preprocessing.py:8: DeprecationWarning: `log1p` is deprecated since scVelo v0.3.0 and will be removed in a future version. Please use `log1p` from `scanpy.pp` instead.
#   scv.pp.log1p(adata)
# Extracted 2000 highly variable genes.
# Data preprocessing complete.

# %%
print('---------------------------------------------------------------')
print('Step 2: Feature extraction in progress...')
    
# a. Statistics-based Feature: expr_2000.csv
feature1 = df0.T.values
print('(1) Statistics-based Feature: expr_2000.csv \t', feature1.shape)
# Out:
# ---------------------------------------------------------------
# Step 2: Feature extraction in progress...
# (1) Statistics-based Feature: expr_2000.csv 	 (2998, 2000)

# %%
# b. Information-based Feature: scPSD      
sys.path.append('scMFF/psdPy') 
from psdPy import psd
X_scPSD = psd(df0.T) 
np.savetxt(dir + 'scPSD_embedding.txt.gz', X_scPSD)
feature2 = X_scPSD
print('(2) Information-based Feature: scPSD_embedding.txt.gz \t', feature2.shape)
# Out:
# (2) Information-based Feature: scPSD_embedding.txt.gz 	 (2998, 2000)

# %%
# c. Matrix Factorization-based Feature: PCA
pca = PCA(n_components=266) 
X_PCA = pca.fit_transform(df0.T)
np.savetxt(dir + 'PCA_embedding.txt.gz', X_PCA)
feature3 = X_PCA
print('(3) Matrix Factorization-based Feature: PCA_embedding.txt.gz \t', feature3.shape)
# Out:
# (3) Matrix Factorization-based Feature: PCA_embedding.txt.gz 	 (2998, 266)

# %%
sys.path.append('scMFF') 
dir_path1 = 'Example_data/'
preprocess_command = f"python -W ignore scGNN/PreprocessingscGNN.py --datasetName expr.csv --datasetDir {dir_path1} --LTMGDir {dir_path1} --filetype CSV --geneSelectnum 2000"    
os.system(preprocess_command)
# Out:
# Step1: Start filter and generating CSV
# Input scRNA data in CSV format is validated, start reading...
# Data loaded, start filtering...
# After preprocessing, 14118 genes remaining
# After preprocessing, 2998 cells have 0.99 nonzero
# Preprocessing Done. Total Running Time: 10.51564908027649 seconds
# 0

# %%
ls
# Out:
# Classifier.py           Model.png         README.md          utils.py
# Example_data/           Preprocessing.py  scGNN/
# Example_data_complete/  psdPy/            scMFF_pipeline.py
# Fusion.py               __pycache__/      test.ipynb

# %%
# d. Deep Learningg-based Feature: scGNN
sys.path.append('scMFF/') 
dir_path1 = '/home/sunnan/BioData/Transcriptome_classification/scMFF/scMFF/Example_data/'
preprocess_command = f"python -W ignore scGNN/PreprocessingscGNN.py --datasetName expr.csv --datasetDir {dir_path1} --LTMGDir {dir_path1} --filetype CSV --geneSelectnum 2000"    
os.system(preprocess_command)

dir_path2 = '/home/sunnan/BioData/Transcriptome_classification/scMFF/scMFF/'
scgnn_command = f"python -W ignore scGNN/scGNN.py --datasetName Example_data --datasetDir {dir_path2} --outputDir {dir_path1} --EM-iteration 2 --Regu-epochs 50 --EM-epochs 20 --quickmode --nonsparseMode"
os.system(scgnn_command)
feature4 = pd.read_csv(dir + 'scGNN_embedding.csv', index_col=0, header=0).values
print('(4) Deep Learningg-based Feature: scGNN_embedding.csv \t', feature4.shape)
# Out:
# Step1: Start filter and generating CSV
# Input scRNA data in CSV format is validated, start reading...
# Data loaded, start filtering...
# After preprocessing, 14118 genes remaining
# After preprocessing, 2998 cells have 0.99 nonzero
# Preprocessing Done. Total Running Time: 10.91727066040039 seconds
# 2025-05-15 15:07:32.561401: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using device:cuda
# ---0:00:00---scRNA starts loading.
# Load expression in csv format
# ---0:00:01---scRNA has been successfully loaded
# ---0:00:01---TrainLoader has been successfully prepared.
# ---0:00:02---Pytorch model ready.
# Start training...
# Train Epoch: 1 [0/2998 (0%)]	Loss: 237.400246
# ====> Epoch: 1 Average loss: 237.4002
# Train Epoch: 2 [0/2998 (0%)]	Loss: 198.652643
# ====> Epoch: 2 Average loss: 198.6526
# Train Epoch: 3 [0/2998 (0%)]	Loss: 189.751564
# ====> Epoch: 3 Average loss: 189.7516
# Train Epoch: 4 [0/2998 (0%)]	Loss: 149.167591
# ====> Epoch: 4 Average loss: 149.1676
# Train Epoch: 5 [0/2998 (0%)]	Loss: 138.537483
# ====> Epoch: 5 Average loss: 138.5375
# Train Epoch: 6 [0/2998 (0%)]	Loss: 128.193358
# ====> Epoch: 6 Average loss: 128.1934
# Train Epoch: 7 [0/2998 (0%)]	Loss: 125.429661
# ====> Epoch: 7 Average loss: 125.4297
# Train Epoch: 8 [0/2998 (0%)]	Loss: 120.841186
# ====> Epoch: 8 Average loss: 120.8412
# Train Epoch: 9 [0/2998 (0%)]	Loss: 114.851484
# ====> Epoch: 9 Average loss: 114.8515
# Train Epoch: 10 [0/2998 (0%)]	Loss: 113.518293
# ====> Epoch: 10 Average loss: 113.5183
# Train Epoch: 11 [0/2998 (0%)]	Loss: 111.102839
# ====> Epoch: 11 Average loss: 111.1028
# Train Epoch: 12 [0/2998 (0%)]	Loss: 108.406729
# ====> Epoch: 12 Average loss: 108.4067
# Train Epoch: 13 [0/2998 (0%)]	Loss: 107.589372
# ====> Epoch: 13 Average loss: 107.5894
# Train Epoch: 14 [0/2998 (0%)]	Loss: 104.732311
# ====> Epoch: 14 Average loss: 104.7323
# Train Epoch: 15 [0/2998 (0%)]	Loss: 102.269388
# ====> Epoch: 15 Average loss: 102.2694
# Train Epoch: 16 [0/2998 (0%)]	Loss: 100.919801
# ====> Epoch: 16 Average loss: 100.9198
# Train Epoch: 17 [0/2998 (0%)]	Loss: 98.593323
# ====> Epoch: 17 Average loss: 98.5933
# Train Epoch: 18 [0/2998 (0%)]	Loss: 96.859854
# ====> Epoch: 18 Average loss: 96.8599
# Train Epoch: 19 [0/2998 (0%)]	Loss: 95.349817
# ====> Epoch: 19 Average loss: 95.3498
# Train Epoch: 20 [0/2998 (0%)]	Loss: 92.962788
# ====> Epoch: 20 Average loss: 92.9628
# Train Epoch: 21 [0/2998 (0%)]	Loss: 91.304526
# ====> Epoch: 21 Average loss: 91.3045
# Train Epoch: 22 [0/2998 (0%)]	Loss: 89.451530
# ====> Epoch: 22 Average loss: 89.4515
# Train Epoch: 23 [0/2998 (0%)]	Loss: 87.650924
# ====> Epoch: 23 Average loss: 87.6509
# Train Epoch: 24 [0/2998 (0%)]	Loss: 86.398182
# ====> Epoch: 24 Average loss: 86.3982
# Train Epoch: 25 [0/2998 (0%)]	Loss: 84.694051
# ====> Epoch: 25 Average loss: 84.6941
# Train Epoch: 26 [0/2998 (0%)]	Loss: 83.338966
# ====> Epoch: 26 Average loss: 83.3390
# Train Epoch: 27 [0/2998 (0%)]	Loss: 82.016714
# ====> Epoch: 27 Average loss: 82.0167
# Train Epoch: 28 [0/2998 (0%)]	Loss: 80.529296
# ====> Epoch: 28 Average loss: 80.5293
# Train Epoch: 29 [0/2998 (0%)]	Loss: 79.350077
# ====> Epoch: 29 Average loss: 79.3501
# Train Epoch: 30 [0/2998 (0%)]	Loss: 77.815460
# ====> Epoch: 30 Average loss: 77.8155
# Train Epoch: 31 [0/2998 (0%)]	Loss: 76.379753
# ====> Epoch: 31 Average loss: 76.3798
# Train Epoch: 32 [0/2998 (0%)]	Loss: 74.787655
# ====> Epoch: 32 Average loss: 74.7877
# Train Epoch: 33 [0/2998 (0%)]	Loss: 73.219073
# ====> Epoch: 33 Average loss: 73.2191
# Train Epoch: 34 [0/2998 (0%)]	Loss: 71.889072
# ====> Epoch: 34 Average loss: 71.8891
# Train Epoch: 35 [0/2998 (0%)]	Loss: 70.469907
# ====> Epoch: 35 Average loss: 70.4699
# Train Epoch: 36 [0/2998 (0%)]	Loss: 69.076588
# ====> Epoch: 36 Average loss: 69.0766
# Train Epoch: 37 [0/2998 (0%)]	Loss: 67.623416
# ====> Epoch: 37 Average loss: 67.6234
# Train Epoch: 38 [0/2998 (0%)]	Loss: 66.211370
# ====> Epoch: 38 Average loss: 66.2114
# Train Epoch: 39 [0/2998 (0%)]	Loss: 64.742339
# ====> Epoch: 39 Average loss: 64.7423
# Train Epoch: 40 [0/2998 (0%)]	Loss: 63.232895
# ====> Epoch: 40 Average loss: 63.2329
# Train Epoch: 41 [0/2998 (0%)]	Loss: 61.692957
# ====> Epoch: 41 Average loss: 61.6930
# Train Epoch: 42 [0/2998 (0%)]	Loss: 60.281823
# ====> Epoch: 42 Average loss: 60.2818
# Train Epoch: 43 [0/2998 (0%)]	Loss: 58.820161
# ====> Epoch: 43 Average loss: 58.8202
# Train Epoch: 44 [0/2998 (0%)]	Loss: 57.507151
# ====> Epoch: 44 Average loss: 57.5072
# Train Epoch: 45 [0/2998 (0%)]	Loss: 56.344084
# ====> Epoch: 45 Average loss: 56.3441
# Train Epoch: 46 [0/2998 (0%)]	Loss: 55.310447
# ====> Epoch: 46 Average loss: 55.3104
# Train Epoch: 47 [0/2998 (0%)]	Loss: 54.387868
# ====> Epoch: 47 Average loss: 54.3879
# Train Epoch: 48 [0/2998 (0%)]	Loss: 53.537004
# ====> Epoch: 48 Average loss: 53.5370
# Train Epoch: 49 [0/2998 (0%)]	Loss: 52.845981
# ====> Epoch: 49 Average loss: 52.8460
# Train Epoch: 50 [0/2998 (0%)]	Loss: 52.272958
# ====> Epoch: 50 Average loss: 52.2730
# zOut ready at 11.469189405441284
# ---0:00:11---Start Prune
# Start pruning 0th cell, cost 7.05718994140625e-05s
# ---0:00:12---Prune Finished
# ---0:00:12---EM process starts
# ---0:00:12---Start 0th iteration.
# Louvain cluster: 22
# ---0:00:13---Clustering Ends
# Total Cluster Number: 11
# Train Epoch: 1 [0/2998 (0%)]	Loss: 51.824623
# ====> Epoch: 1 Average loss: 51.8246
# Train Epoch: 2 [0/2998 (0%)]	Loss: 51.448361
# ====> Epoch: 2 Average loss: 51.4484
# Train Epoch: 3 [0/2998 (0%)]	Loss: 51.128231
# ====> Epoch: 3 Average loss: 51.1282
# Train Epoch: 4 [0/2998 (0%)]	Loss: 50.848112
# ====> Epoch: 4 Average loss: 50.8481
# Train Epoch: 5 [0/2998 (0%)]	Loss: 50.608885
# ====> Epoch: 5 Average loss: 50.6089
# Train Epoch: 6 [0/2998 (0%)]	Loss: 50.404957
# ====> Epoch: 6 Average loss: 50.4050
# Train Epoch: 7 [0/2998 (0%)]	Loss: 50.213001
# ====> Epoch: 7 Average loss: 50.2130
# Train Epoch: 8 [0/2998 (0%)]	Loss: 50.031208
# ====> Epoch: 8 Average loss: 50.0312
# Train Epoch: 9 [0/2998 (0%)]	Loss: 49.835891
# ====> Epoch: 9 Average loss: 49.8359
# Train Epoch: 10 [0/2998 (0%)]	Loss: 49.636862
# ====> Epoch: 10 Average loss: 49.6369
# Train Epoch: 11 [0/2998 (0%)]	Loss: 49.442097
# ====> Epoch: 11 Average loss: 49.4421
# Train Epoch: 12 [0/2998 (0%)]	Loss: 49.250141
# ====> Epoch: 12 Average loss: 49.2501
# Train Epoch: 13 [0/2998 (0%)]	Loss: 49.073497
# ====> Epoch: 13 Average loss: 49.0735
# Train Epoch: 14 [0/2998 (0%)]	Loss: 48.908533
# ====> Epoch: 14 Average loss: 48.9085
# Train Epoch: 15 [0/2998 (0%)]	Loss: 48.748838
# ====> Epoch: 15 Average loss: 48.7488
# Train Epoch: 16 [0/2998 (0%)]	Loss: 48.602433
# ====> Epoch: 16 Average loss: 48.6024
# Train Epoch: 17 [0/2998 (0%)]	Loss: 48.465586
# ====> Epoch: 17 Average loss: 48.4656
# Train Epoch: 18 [0/2998 (0%)]	Loss: 48.323966
# ====> Epoch: 18 Average loss: 48.3240
# Train Epoch: 19 [0/2998 (0%)]	Loss: 48.163432
# ====> Epoch: 19 Average loss: 48.1634
# Train Epoch: 20 [0/2998 (0%)]	Loss: 47.984995
# ====> Epoch: 20 Average loss: 47.9850
# ---0:00:18---Start Prune
# Start pruning 0th cell, cost 8.0108642578125e-05s
# ---0:00:19---Prune Finished
# ---0:00:19---Start test converge condition
# celltype similarity:0.0
# ---0:00:19---0th iteration in EM Finished
# ---0:00:19---Start 1th iteration.
# Louvain cluster: 22
# ---0:00:20---Clustering Ends
# Total Cluster Number: 11
# Train Epoch: 1 [0/2998 (0%)]	Loss: 47.813667
# ====> Epoch: 1 Average loss: 47.8137
# Train Epoch: 2 [0/2998 (0%)]	Loss: 47.668268
# ====> Epoch: 2 Average loss: 47.6683
# Train Epoch: 3 [0/2998 (0%)]	Loss: 47.550841
# ====> Epoch: 3 Average loss: 47.5508
# Train Epoch: 4 [0/2998 (0%)]	Loss: 47.451999
# ====> Epoch: 4 Average loss: 47.4520
# Train Epoch: 5 [0/2998 (0%)]	Loss: 47.367651
# ====> Epoch: 5 Average loss: 47.3677
# Train Epoch: 6 [0/2998 (0%)]	Loss: 47.292070
# ====> Epoch: 6 Average loss: 47.2921
# Train Epoch: 7 [0/2998 (0%)]	Loss: 47.151127
# ====> Epoch: 7 Average loss: 47.1511
# Train Epoch: 8 [0/2998 (0%)]	Loss: 46.953849
# ====> Epoch: 8 Average loss: 46.9538
# Train Epoch: 9 [0/2998 (0%)]	Loss: 46.773964
# ====> Epoch: 9 Average loss: 46.7740
# Train Epoch: 10 [0/2998 (0%)]	Loss: 46.675263
# ====> Epoch: 10 Average loss: 46.6753
# Train Epoch: 11 [0/2998 (0%)]	Loss: 46.591947
# ====> Epoch: 11 Average loss: 46.5919
# Train Epoch: 12 [0/2998 (0%)]	Loss: 46.449101
# ====> Epoch: 12 Average loss: 46.4491
# Train Epoch: 13 [0/2998 (0%)]	Loss: 46.269992
# ====> Epoch: 13 Average loss: 46.2700
# Train Epoch: 14 [0/2998 (0%)]	Loss: 46.104929
# ====> Epoch: 14 Average loss: 46.1049
# Train Epoch: 15 [0/2998 (0%)]	Loss: 45.977620
# ====> Epoch: 15 Average loss: 45.9776
# Train Epoch: 16 [0/2998 (0%)]	Loss: 45.884887
# ====> Epoch: 16 Average loss: 45.8849
# Train Epoch: 17 [0/2998 (0%)]	Loss: 45.836162
# ====> Epoch: 17 Average loss: 45.8362
# Train Epoch: 18 [0/2998 (0%)]	Loss: 45.810978
# ====> Epoch: 18 Average loss: 45.8110
# Train Epoch: 19 [0/2998 (0%)]	Loss: 45.653034
# ====> Epoch: 19 Average loss: 45.6530
# Train Epoch: 20 [0/2998 (0%)]	Loss: 45.418154
# ====> Epoch: 20 Average loss: 45.4182
# ---0:00:24---Start Prune
# Start pruning 0th cell, cost 7.367134094238281e-05s
# ---0:00:25---Prune Finished
# ---0:00:25---Start test converge condition
# celltype similarity:0.7571773857253645
# ---0:00:25---1th iteration in EM Finished
# ---0:00:25---Starts Imputation
# Train Epoch: 1 [0/2998 (0%)]	Loss: 76300.717812
# ====> Epoch: 1 Average loss: 76300.7178
# Train Epoch: 2 [0/2998 (0%)]	Loss: 64858.300200
# ====> Epoch: 2 Average loss: 64858.3002
# Train Epoch: 3 [0/2998 (0%)]	Loss: 60873.446298
# ====> Epoch: 3 Average loss: 60873.4463
# Train Epoch: 4 [0/2998 (0%)]	Loss: 48436.002668
# ====> Epoch: 4 Average loss: 48436.0027
# Train Epoch: 5 [0/2998 (0%)]	Loss: 44005.715811
# ====> Epoch: 5 Average loss: 44005.7158
# Train Epoch: 6 [0/2998 (0%)]	Loss: 39775.423616
# ====> Epoch: 6 Average loss: 39775.4236
# Train Epoch: 7 [0/2998 (0%)]	Loss: 38338.305537
# ====> Epoch: 7 Average loss: 38338.3055
# Train Epoch: 8 [0/2998 (0%)]	Loss: 35476.280187
# ====> Epoch: 8 Average loss: 35476.2802
# Train Epoch: 9 [0/2998 (0%)]	Loss: 33564.005337
# ====> Epoch: 9 Average loss: 33564.0053
# Train Epoch: 10 [0/2998 (0%)]	Loss: 32571.935957
# ====> Epoch: 10 Average loss: 32571.9360
# Train Epoch: 11 [0/2998 (0%)]	Loss: 31377.286191
# ====> Epoch: 11 Average loss: 31377.2862
# Train Epoch: 12 [0/2998 (0%)]	Loss: 30896.221481
# ====> Epoch: 12 Average loss: 30896.2215
# Train Epoch: 13 [0/2998 (0%)]	Loss: 30052.061374
# ====> Epoch: 13 Average loss: 30052.0614
# Train Epoch: 14 [0/2998 (0%)]	Loss: 29128.867245
# ====> Epoch: 14 Average loss: 29128.8672
# Train Epoch: 15 [0/2998 (0%)]	Loss: 28603.551701
# ====> Epoch: 15 Average loss: 28603.5517
# Train Epoch: 16 [0/2998 (0%)]	Loss: 27841.256838
# ====> Epoch: 16 Average loss: 27841.2568
# Train Epoch: 17 [0/2998 (0%)]	Loss: 27201.299533
# ====> Epoch: 17 Average loss: 27201.2995
# Train Epoch: 18 [0/2998 (0%)]	Loss: 26513.683789
# ====> Epoch: 18 Average loss: 26513.6838
# Train Epoch: 19 [0/2998 (0%)]	Loss: 25718.270847
# ====> Epoch: 19 Average loss: 25718.2708
# Train Epoch: 20 [0/2998 (0%)]	Loss: 25167.068712
# ====> Epoch: 20 Average loss: 25167.0687
# ---0:00:30---All iterations finished, start output results.
# ---0:00:31---scGNN finished
# (4) Deep Learningg-based Feature: scGNN_embedding.csv 	 (2998, 128)

# %%
print('Feature extraction complete.')
# Out:
# Feature extraction complete.

# %%
####        Step 3: Cross Fusion Mudule          ########################################################
print('---------------------------------------------------------------')
print('Step 3: Cross Fusion in progress...')
[n_sample, n_feature] = feature1.shape
Fusion_sum, Fusion_hadamard, Fusion_attention = [], [], []
Fused_moe, Fused_residual, Fused_transformer = [], [], []

i = 0
max_dim = max(len(feature1[i, :]), len(feature2[i, :]), len(feature3[i, :]), len(feature4[i, :]))
output_dim = min(len(feature1[i, :]), len(feature2[i, :]), len(feature3[i, :]), len(feature4[i, :]))
   
moefusion = MoEFusion(max_dim * 4, output_dim)
residualfusion = ResidualFusion(max_dim, output_dim)
transformerfusion = TransformerConcatFusion(max_dim, output_dim)

for i in range(n_sample):
    print('The '+str(i+1)+'-th cell embedding')
    weights = [1/4, 1/4, 1/4, 1/4] 
    fusion_sum = weighted_sum_fusion([feature1[i,:], feature2[i,:], feature3[i,:], feature4[i,:]], weights)
    fusion_hadamard = hadamard_product_fusion([feature1[i,:], feature2[i,:], feature3[i,:], feature4[i,:]])
        
    features = [torch.tensor(feature1[i,:], dtype=torch.float32), torch.tensor(feature2[i,:], dtype=torch.float32), torch.tensor(feature3[i,:], dtype=torch.float32), torch.tensor(feature4[i,:], dtype=torch.float32)]
    labels = torch.tensor(Y[i])    
    AttentionFusion_model = train_AttentionFusion(features, labels, num_classes)
    fusion_attention,logits = AttentionFusion_model(features)

    Fusion_sum.append(fusion_sum)
    Fusion_hadamard.append(fusion_hadamard)
    Fusion_attention.append(fusion_attention.detach().cpu().numpy())

    f1 = zero_pad_feature(feature1[i, :],max_dim)
    f2 = zero_pad_feature(feature2[i, :],max_dim)
    f3 = zero_pad_feature(feature3[i, :],max_dim)
    f4 = zero_pad_feature(feature4[i, :],max_dim) 

    fused_moe = moefusion(f1, f2, f3, f4)
    fused_residual = residualfusion(f1, f2, f3, f4)
    fused_transformer = transformerfusion(f1, f2, f3, f4)  

    Fused_moe.append(fused_moe)
    Fused_residual.append(fused_residual)
    Fused_transformer.append(fused_transformer)
# Out:
# ---------------------------------------------------------------
# Step 3: Cross Fusion in progress...
# The 1-th cell embedding
# The 2-th cell embedding
# The 3-th cell embedding
# The 4-th cell embedding
# The 5-th cell embedding
# The 6-th cell embedding
# The 7-th cell embedding
# The 8-th cell embedding
# The 9-th cell embedding
# The 10-th cell embedding
# The 11-th cell embedding
# The 12-th cell embedding
# The 13-th cell embedding
# The 14-th cell embedding
# The 15-th cell embedding
# The 16-th cell embedding
# The 17-th cell embedding
# The 18-th cell embedding
# The 19-th cell embedding
# The 20-th cell embedding
# The 21-th cell embedding
# The 22-th cell embedding
# The 23-th cell embedding
# The 24-th cell embedding
# The 25-th cell embedding
# The 26-th cell embedding
# The 27-th cell embedding
# The 28-th cell embedding
# The 29-th cell embedding
# The 30-th cell embedding
# The 31-th cell embedding
# The 32-th cell embedding
# The 33-th cell embedding
# The 34-th cell embedding
# The 35-th cell embedding
# The 36-th cell embedding
# The 37-th cell embedding
# The 38-th cell embedding
# The 39-th cell embedding
# The 40-th cell embedding
# The 41-th cell embedding
# The 42-th cell embedding
# The 43-th cell embedding
# The 44-th cell embedding
# The 45-th cell embedding
# The 46-th cell embedding
# The 47-th cell embedding
# The 48-th cell embedding
# The 49-th cell embedding
# The 50-th cell embedding
# The 51-th cell embedding
# The 52-th cell embedding
# The 53-th cell embedding
# The 54-th cell embedding
# The 55-th cell embedding
# The 56-th cell embedding
# The 57-th cell embedding
# The 58-th cell embedding
# The 59-th cell embedding
# The 60-th cell embedding
# The 61-th cell embedding
# The 62-th cell embedding
# The 63-th cell embedding
# The 64-th cell embedding
# The 65-th cell embedding
# The 66-th cell embedding
# The 67-th cell embedding
# The 68-th cell embedding
# The 69-th cell embedding
# The 70-th cell embedding
# The 71-th cell embedding
# The 72-th cell embedding
# The 73-th cell embedding
# The 74-th cell embedding
# The 75-th cell embedding
# The 76-th cell embedding
# The 77-th cell embedding
# The 78-th cell embedding
# The 79-th cell embedding
# The 80-th cell embedding
# The 81-th cell embedding
# The 82-th cell embedding
# The 83-th cell embedding
# The 84-th cell embedding
# The 85-th cell embedding
# The 86-th cell embedding
# The 87-th cell embedding
# The 88-th cell embedding
# The 89-th cell embedding
# The 90-th cell embedding
# The 91-th cell embedding
# The 92-th cell embedding
# The 93-th cell embedding
# The 94-th cell embedding
# The 95-th cell embedding
# The 96-th cell embedding
# The 97-th cell embedding
# The 98-th cell embedding
# The 99-th cell embedding
# The 100-th cell embedding
# The 101-th cell embedding
# The 102-th cell embedding
# The 103-th cell embedding
# The 104-th cell embedding
# The 105-th cell embedding
# The 106-th cell embedding
# The 107-th cell embedding
# The 108-th cell embedding
# The 109-th cell embedding
# The 110-th cell embedding
# The 111-th cell embedding
# The 112-th cell embedding
# The 113-th cell embedding
# The 114-th cell embedding
# The 115-th cell embedding
# The 116-th cell embedding
# The 117-th cell embedding
# The 118-th cell embedding
# The 119-th cell embedding
# The 120-th cell embedding
# The 121-th cell embedding
# The 122-th cell embedding
# The 123-th cell embedding
# The 124-th cell embedding
# The 125-th cell embedding
# The 126-th cell embedding
# The 127-th cell embedding
# The 128-th cell embedding
# The 129-th cell embedding
# The 130-th cell embedding
# The 131-th cell embedding
# The 132-th cell embedding
# The 133-th cell embedding
# The 134-th cell embedding
# The 135-th cell embedding
# The 136-th cell embedding
# The 137-th cell embedding
# The 138-th cell embedding
# The 139-th cell embedding
# The 140-th cell embedding
# The 141-th cell embedding
# The 142-th cell embedding
# The 143-th cell embedding
# The 144-th cell embedding
# The 145-th cell embedding
# The 146-th cell embedding
# The 147-th cell embedding
# The 148-th cell embedding
# The 149-th cell embedding
# The 150-th cell embedding
# The 151-th cell embedding
# The 152-th cell embedding
# The 153-th cell embedding
# The 154-th cell embedding
# The 155-th cell embedding
# The 156-th cell embedding
# The 157-th cell embedding
# The 158-th cell embedding
# The 159-th cell embedding
# The 160-th cell embedding
# The 161-th cell embedding
# The 162-th cell embedding
# The 163-th cell embedding
# The 164-th cell embedding
# The 165-th cell embedding
# The 166-th cell embedding
# The 167-th cell embedding
# The 168-th cell embedding
# The 169-th cell embedding
# The 170-th cell embedding
# The 171-th cell embedding
# The 172-th cell embedding
# The 173-th cell embedding
# The 174-th cell embedding
# The 175-th cell embedding
# The 176-th cell embedding
# The 177-th cell embedding
# The 178-th cell embedding
# The 179-th cell embedding
# The 180-th cell embedding
# The 181-th cell embedding
# The 182-th cell embedding
# The 183-th cell embedding
# The 184-th cell embedding
# The 185-th cell embedding
# The 186-th cell embedding
# The 187-th cell embedding
# The 188-th cell embedding
# The 189-th cell embedding
# The 190-th cell embedding
# The 191-th cell embedding
# The 192-th cell embedding
# The 193-th cell embedding
# The 194-th cell embedding
# The 195-th cell embedding
# The 196-th cell embedding
# The 197-th cell embedding
# The 198-th cell embedding
# The 199-th cell embedding
# The 200-th cell embedding
# The 201-th cell embedding
# The 202-th cell embedding
# The 203-th cell embedding
# The 204-th cell embedding
# The 205-th cell embedding
# The 206-th cell embedding
# The 207-th cell embedding
# The 208-th cell embedding
# The 209-th cell embedding
# The 210-th cell embedding
# The 211-th cell embedding
# The 212-th cell embedding
# The 213-th cell embedding
# The 214-th cell embedding
# The 215-th cell embedding
# The 216-th cell embedding
# The 217-th cell embedding
# The 218-th cell embedding
# The 219-th cell embedding
# The 220-th cell embedding
# The 221-th cell embedding
# The 222-th cell embedding
# The 223-th cell embedding
# The 224-th cell embedding
# The 225-th cell embedding
# The 226-th cell embedding
# The 227-th cell embedding
# The 228-th cell embedding
# The 229-th cell embedding
# The 230-th cell embedding
# The 231-th cell embedding
# The 232-th cell embedding
# The 233-th cell embedding
# The 234-th cell embedding
# The 235-th cell embedding
# The 236-th cell embedding
# The 237-th cell embedding
# The 238-th cell embedding
# The 239-th cell embedding
# The 240-th cell embedding
# The 241-th cell embedding
# The 242-th cell embedding
# The 243-th cell embedding
# The 244-th cell embedding
# The 245-th cell embedding
# The 246-th cell embedding
# The 247-th cell embedding
# The 248-th cell embedding
# The 249-th cell embedding
# The 250-th cell embedding
# The 251-th cell embedding
# The 252-th cell embedding
# The 253-th cell embedding
# The 254-th cell embedding
# The 255-th cell embedding
# The 256-th cell embedding
# The 257-th cell embedding
# The 258-th cell embedding
# The 259-th cell embedding
# The 260-th cell embedding
# The 261-th cell embedding
# The 262-th cell embedding
# The 263-th cell embedding
# The 264-th cell embedding
# The 265-th cell embedding
# The 266-th cell embedding
# The 267-th cell embedding
# The 268-th cell embedding
# The 269-th cell embedding
# The 270-th cell embedding
# The 271-th cell embedding
# The 272-th cell embedding
# The 273-th cell embedding
# The 274-th cell embedding
# The 275-th cell embedding
# The 276-th cell embedding
# The 277-th cell embedding
# The 278-th cell embedding
# The 279-th cell embedding
# The 280-th cell embedding
# The 281-th cell embedding
# The 282-th cell embedding
# The 283-th cell embedding
# The 284-th cell embedding
# The 285-th cell embedding
# The 286-th cell embedding
# The 287-th cell embedding
# The 288-th cell embedding
# The 289-th cell embedding
# The 290-th cell embedding
# The 291-th cell embedding
# The 292-th cell embedding
# The 293-th cell embedding
# The 294-th cell embedding
# The 295-th cell embedding
# The 296-th cell embedding
# The 297-th cell embedding
# The 298-th cell embedding
# The 299-th cell embedding
# The 300-th cell embedding
# The 301-th cell embedding
# The 302-th cell embedding
# The 303-th cell embedding
# The 304-th cell embedding
# The 305-th cell embedding
# The 306-th cell embedding
# The 307-th cell embedding
# The 308-th cell embedding
# The 309-th cell embedding
# The 310-th cell embedding
# The 311-th cell embedding
# The 312-th cell embedding
# The 313-th cell embedding
# The 314-th cell embedding
# The 315-th cell embedding
# The 316-th cell embedding
# The 317-th cell embedding
# The 318-th cell embedding
# The 319-th cell embedding
# The 320-th cell embedding
# The 321-th cell embedding
# The 322-th cell embedding
# The 323-th cell embedding
# The 324-th cell embedding
# The 325-th cell embedding
# The 326-th cell embedding
# The 327-th cell embedding
# The 328-th cell embedding
# The 329-th cell embedding
# The 330-th cell embedding
# The 331-th cell embedding
# The 332-th cell embedding
# The 333-th cell embedding
# The 334-th cell embedding
# The 335-th cell embedding
# The 336-th cell embedding
# The 337-th cell embedding
# The 338-th cell embedding
# The 339-th cell embedding
# The 340-th cell embedding
# The 341-th cell embedding
# The 342-th cell embedding
# The 343-th cell embedding
# The 344-th cell embedding
# The 345-th cell embedding
# The 346-th cell embedding
# The 347-th cell embedding
# The 348-th cell embedding
# The 349-th cell embedding
# The 350-th cell embedding
# The 351-th cell embedding
# The 352-th cell embedding
# The 353-th cell embedding
# The 354-th cell embedding
# The 355-th cell embedding
# The 356-th cell embedding
# The 357-th cell embedding
# The 358-th cell embedding
# The 359-th cell embedding
# The 360-th cell embedding
# The 361-th cell embedding
# The 362-th cell embedding
# The 363-th cell embedding
# The 364-th cell embedding
# The 365-th cell embedding
# The 366-th cell embedding
# The 367-th cell embedding
# The 368-th cell embedding
# The 369-th cell embedding
# The 370-th cell embedding
# The 371-th cell embedding
# The 372-th cell embedding
# The 373-th cell embedding
# The 374-th cell embedding
# The 375-th cell embedding
# The 376-th cell embedding
# The 377-th cell embedding
# The 378-th cell embedding
# The 379-th cell embedding
# The 380-th cell embedding
# The 381-th cell embedding
# The 382-th cell embedding
# The 383-th cell embedding
# The 384-th cell embedding
# The 385-th cell embedding
# The 386-th cell embedding
# The 387-th cell embedding
# The 388-th cell embedding
# The 389-th cell embedding
# The 390-th cell embedding
# The 391-th cell embedding
# The 392-th cell embedding
# The 393-th cell embedding
# The 394-th cell embedding
# The 395-th cell embedding
# The 396-th cell embedding
# The 397-th cell embedding
# The 398-th cell embedding
# The 399-th cell embedding
# The 400-th cell embedding
# The 401-th cell embedding
# The 402-th cell embedding
# The 403-th cell embedding
# The 404-th cell embedding
# The 405-th cell embedding
# The 406-th cell embedding
# The 407-th cell embedding
# The 408-th cell embedding
# The 409-th cell embedding
# The 410-th cell embedding
# The 411-th cell embedding
# The 412-th cell embedding
# The 413-th cell embedding
# The 414-th cell embedding
# The 415-th cell embedding
# The 416-th cell embedding
# The 417-th cell embedding
# The 418-th cell embedding
# The 419-th cell embedding
# The 420-th cell embedding
# The 421-th cell embedding
# The 422-th cell embedding
# The 423-th cell embedding
# The 424-th cell embedding
# The 425-th cell embedding
# The 426-th cell embedding
# The 427-th cell embedding
# The 428-th cell embedding
# The 429-th cell embedding
# The 430-th cell embedding
# The 431-th cell embedding
# The 432-th cell embedding
# The 433-th cell embedding
# The 434-th cell embedding
# The 435-th cell embedding
# The 436-th cell embedding
# The 437-th cell embedding
# The 438-th cell embedding
# The 439-th cell embedding
# The 440-th cell embedding
# The 441-th cell embedding
# The 442-th cell embedding
# The 443-th cell embedding
# The 444-th cell embedding
# The 445-th cell embedding
# The 446-th cell embedding
# The 447-th cell embedding
# The 448-th cell embedding
# The 449-th cell embedding
# The 450-th cell embedding
# The 451-th cell embedding
# The 452-th cell embedding
# The 453-th cell embedding
# The 454-th cell embedding
# The 455-th cell embedding
# The 456-th cell embedding
# The 457-th cell embedding
# The 458-th cell embedding
# The 459-th cell embedding
# The 460-th cell embedding
# The 461-th cell embedding
# The 462-th cell embedding
# The 463-th cell embedding
# The 464-th cell embedding
# The 465-th cell embedding
# The 466-th cell embedding
# The 467-th cell embedding
# The 468-th cell embedding
# The 469-th cell embedding
# The 470-th cell embedding
# The 471-th cell embedding
# The 472-th cell embedding
# The 473-th cell embedding
# The 474-th cell embedding
# The 475-th cell embedding
# The 476-th cell embedding
# The 477-th cell embedding
# The 478-th cell embedding
# The 479-th cell embedding
# The 480-th cell embedding
# The 481-th cell embedding
# The 482-th cell embedding
# The 483-th cell embedding
# The 484-th cell embedding
# The 485-th cell embedding
# The 486-th cell embedding
# The 487-th cell embedding
# The 488-th cell embedding
# The 489-th cell embedding
# The 490-th cell embedding
# The 491-th cell embedding
# The 492-th cell embedding
# The 493-th cell embedding
# The 494-th cell embedding
# The 495-th cell embedding
# The 496-th cell embedding
# The 497-th cell embedding
# The 498-th cell embedding
# The 499-th cell embedding
# The 500-th cell embedding
# The 501-th cell embedding
# The 502-th cell embedding
# The 503-th cell embedding
# The 504-th cell embedding
# The 505-th cell embedding
# The 506-th cell embedding
# The 507-th cell embedding
# The 508-th cell embedding
# The 509-th cell embedding
# The 510-th cell embedding
# The 511-th cell embedding
# The 512-th cell embedding
# The 513-th cell embedding
# The 514-th cell embedding
# The 515-th cell embedding
# The 516-th cell embedding
# The 517-th cell embedding
# The 518-th cell embedding
# The 519-th cell embedding
# The 520-th cell embedding
# The 521-th cell embedding
# The 522-th cell embedding
# The 523-th cell embedding
# The 524-th cell embedding
# The 525-th cell embedding
# The 526-th cell embedding
# The 527-th cell embedding
# The 528-th cell embedding
# The 529-th cell embedding
# The 530-th cell embedding
# The 531-th cell embedding
# The 532-th cell embedding
# The 533-th cell embedding
# The 534-th cell embedding
# The 535-th cell embedding
# The 536-th cell embedding
# The 537-th cell embedding
# The 538-th cell embedding
# The 539-th cell embedding
# The 540-th cell embedding
# The 541-th cell embedding
# The 542-th cell embedding
# The 543-th cell embedding
# The 544-th cell embedding
# The 545-th cell embedding
# The 546-th cell embedding
# The 547-th cell embedding
# The 548-th cell embedding
# The 549-th cell embedding
# The 550-th cell embedding
# The 551-th cell embedding
# The 552-th cell embedding
# The 553-th cell embedding
# The 554-th cell embedding
# The 555-th cell embedding
# The 556-th cell embedding
# The 557-th cell embedding
# The 558-th cell embedding
# The 559-th cell embedding
# The 560-th cell embedding
# The 561-th cell embedding
# The 562-th cell embedding
# The 563-th cell embedding
# The 564-th cell embedding
# The 565-th cell embedding
# The 566-th cell embedding
# The 567-th cell embedding
# The 568-th cell embedding
# The 569-th cell embedding
# The 570-th cell embedding
# The 571-th cell embedding
# The 572-th cell embedding
# The 573-th cell embedding
# The 574-th cell embedding
# The 575-th cell embedding
# The 576-th cell embedding
# The 577-th cell embedding
# The 578-th cell embedding
# The 579-th cell embedding
# The 580-th cell embedding
# The 581-th cell embedding
# The 582-th cell embedding
# The 583-th cell embedding
# The 584-th cell embedding
# The 585-th cell embedding
# The 586-th cell embedding
# The 587-th cell embedding
# The 588-th cell embedding
# The 589-th cell embedding
# The 590-th cell embedding
# The 591-th cell embedding
# The 592-th cell embedding
# The 593-th cell embedding
# The 594-th cell embedding
# The 595-th cell embedding
# The 596-th cell embedding
# The 597-th cell embedding
# The 598-th cell embedding
# The 599-th cell embedding
# The 600-th cell embedding
# The 601-th cell embedding
# The 602-th cell embedding
# The 603-th cell embedding
# The 604-th cell embedding
# The 605-th cell embedding
# The 606-th cell embedding
# The 607-th cell embedding
# The 608-th cell embedding
# The 609-th cell embedding
# The 610-th cell embedding
# The 611-th cell embedding
# The 612-th cell embedding
# The 613-th cell embedding
# The 614-th cell embedding
# The 615-th cell embedding
# The 616-th cell embedding
# The 617-th cell embedding
# The 618-th cell embedding
# The 619-th cell embedding
# The 620-th cell embedding
# The 621-th cell embedding
# The 622-th cell embedding
# The 623-th cell embedding
# The 624-th cell embedding
# The 625-th cell embedding
# The 626-th cell embedding
# The 627-th cell embedding
# The 628-th cell embedding
# The 629-th cell embedding
# The 630-th cell embedding
# The 631-th cell embedding
# The 632-th cell embedding
# The 633-th cell embedding
# The 634-th cell embedding
# The 635-th cell embedding
# The 636-th cell embedding
# The 637-th cell embedding
# The 638-th cell embedding
# The 639-th cell embedding
# The 640-th cell embedding
# The 641-th cell embedding
# The 642-th cell embedding
# The 643-th cell embedding
# The 644-th cell embedding
# The 645-th cell embedding
# The 646-th cell embedding
# The 647-th cell embedding
# The 648-th cell embedding
# The 649-th cell embedding
# The 650-th cell embedding
# The 651-th cell embedding
# The 652-th cell embedding
# The 653-th cell embedding
# The 654-th cell embedding
# The 655-th cell embedding
# The 656-th cell embedding
# The 657-th cell embedding
# The 658-th cell embedding
# The 659-th cell embedding
# The 660-th cell embedding
# The 661-th cell embedding
# The 662-th cell embedding
# The 663-th cell embedding
# The 664-th cell embedding
# The 665-th cell embedding
# The 666-th cell embedding
# The 667-th cell embedding
# The 668-th cell embedding
# The 669-th cell embedding
# The 670-th cell embedding
# The 671-th cell embedding
# The 672-th cell embedding
# The 673-th cell embedding
# The 674-th cell embedding
# The 675-th cell embedding
# The 676-th cell embedding
# The 677-th cell embedding
# The 678-th cell embedding
# The 679-th cell embedding
# The 680-th cell embedding
# The 681-th cell embedding
# The 682-th cell embedding
# The 683-th cell embedding
# The 684-th cell embedding
# The 685-th cell embedding
# The 686-th cell embedding
# The 687-th cell embedding
# The 688-th cell embedding
# The 689-th cell embedding
# The 690-th cell embedding
# The 691-th cell embedding
# The 692-th cell embedding
# The 693-th cell embedding
# The 694-th cell embedding
# The 695-th cell embedding
# The 696-th cell embedding
# The 697-th cell embedding
# The 698-th cell embedding
# The 699-th cell embedding
# The 700-th cell embedding
# The 701-th cell embedding
# The 702-th cell embedding
# The 703-th cell embedding
# The 704-th cell embedding
# The 705-th cell embedding
# The 706-th cell embedding
# The 707-th cell embedding
# The 708-th cell embedding
# The 709-th cell embedding
# The 710-th cell embedding
# The 711-th cell embedding
# The 712-th cell embedding
# The 713-th cell embedding
# The 714-th cell embedding
# The 715-th cell embedding
# The 716-th cell embedding
# The 717-th cell embedding
# The 718-th cell embedding
# The 719-th cell embedding
# The 720-th cell embedding
# The 721-th cell embedding
# The 722-th cell embedding
# The 723-th cell embedding
# The 724-th cell embedding
# The 725-th cell embedding
# The 726-th cell embedding
# The 727-th cell embedding
# The 728-th cell embedding
# The 729-th cell embedding
# The 730-th cell embedding
# The 731-th cell embedding
# The 732-th cell embedding
# The 733-th cell embedding
# The 734-th cell embedding
# The 735-th cell embedding
# The 736-th cell embedding
# The 737-th cell embedding
# The 738-th cell embedding
# The 739-th cell embedding
# The 740-th cell embedding
# The 741-th cell embedding
# The 742-th cell embedding
# The 743-th cell embedding
# The 744-th cell embedding
# The 745-th cell embedding
# The 746-th cell embedding
# The 747-th cell embedding
# The 748-th cell embedding
# The 749-th cell embedding
# The 750-th cell embedding
# The 751-th cell embedding
# The 752-th cell embedding
# The 753-th cell embedding
# The 754-th cell embedding
# The 755-th cell embedding
# The 756-th cell embedding
# The 757-th cell embedding
# The 758-th cell embedding
# The 759-th cell embedding
# The 760-th cell embedding
# The 761-th cell embedding
# The 762-th cell embedding
# The 763-th cell embedding
# The 764-th cell embedding
# The 765-th cell embedding
# The 766-th cell embedding
# The 767-th cell embedding
# The 768-th cell embedding
# The 769-th cell embedding
# The 770-th cell embedding
# The 771-th cell embedding
# The 772-th cell embedding
# The 773-th cell embedding
# The 774-th cell embedding
# The 775-th cell embedding
# The 776-th cell embedding
# The 777-th cell embedding
# The 778-th cell embedding
# The 779-th cell embedding
# The 780-th cell embedding
# The 781-th cell embedding
# The 782-th cell embedding
# The 783-th cell embedding
# The 784-th cell embedding
# The 785-th cell embedding
# The 786-th cell embedding
# The 787-th cell embedding
# The 788-th cell embedding
# The 789-th cell embedding
# The 790-th cell embedding
# The 791-th cell embedding
# The 792-th cell embedding
# The 793-th cell embedding
# The 794-th cell embedding
# The 795-th cell embedding
# The 796-th cell embedding
# The 797-th cell embedding
# The 798-th cell embedding
# The 799-th cell embedding
# The 800-th cell embedding
# The 801-th cell embedding
# The 802-th cell embedding
# The 803-th cell embedding
# The 804-th cell embedding
# The 805-th cell embedding
# The 806-th cell embedding
# The 807-th cell embedding
# The 808-th cell embedding
# The 809-th cell embedding
# The 810-th cell embedding
# The 811-th cell embedding
# The 812-th cell embedding
# The 813-th cell embedding
# The 814-th cell embedding
# The 815-th cell embedding
# The 816-th cell embedding
# The 817-th cell embedding
# The 818-th cell embedding
# The 819-th cell embedding
# The 820-th cell embedding
# The 821-th cell embedding
# The 822-th cell embedding
# The 823-th cell embedding
# The 824-th cell embedding
# The 825-th cell embedding
# The 826-th cell embedding
# The 827-th cell embedding
# The 828-th cell embedding
# The 829-th cell embedding
# The 830-th cell embedding
# The 831-th cell embedding
# The 832-th cell embedding
# The 833-th cell embedding
# The 834-th cell embedding
# The 835-th cell embedding
# The 836-th cell embedding
# The 837-th cell embedding
# The 838-th cell embedding
# The 839-th cell embedding
# The 840-th cell embedding
# The 841-th cell embedding
# The 842-th cell embedding
# The 843-th cell embedding
# The 844-th cell embedding
# The 845-th cell embedding
# The 846-th cell embedding
# The 847-th cell embedding
# The 848-th cell embedding
# The 849-th cell embedding
# The 850-th cell embedding
# The 851-th cell embedding
# The 852-th cell embedding
# The 853-th cell embedding
# The 854-th cell embedding
# The 855-th cell embedding
# The 856-th cell embedding
# The 857-th cell embedding
# The 858-th cell embedding
# The 859-th cell embedding
# The 860-th cell embedding
# The 861-th cell embedding
# The 862-th cell embedding
# The 863-th cell embedding
# The 864-th cell embedding
# The 865-th cell embedding
# The 866-th cell embedding
# The 867-th cell embedding
# The 868-th cell embedding
# The 869-th cell embedding
# The 870-th cell embedding
# The 871-th cell embedding
# The 872-th cell embedding
# The 873-th cell embedding
# The 874-th cell embedding
# The 875-th cell embedding
# The 876-th cell embedding
# The 877-th cell embedding
# The 878-th cell embedding
# The 879-th cell embedding
# The 880-th cell embedding
# The 881-th cell embedding
# The 882-th cell embedding
# The 883-th cell embedding
# The 884-th cell embedding
# The 885-th cell embedding
# The 886-th cell embedding
# The 887-th cell embedding
# The 888-th cell embedding
# The 889-th cell embedding
# The 890-th cell embedding
# The 891-th cell embedding
# The 892-th cell embedding
# The 893-th cell embedding
# The 894-th cell embedding
# The 895-th cell embedding
# The 896-th cell embedding
# The 897-th cell embedding
# The 898-th cell embedding
# The 899-th cell embedding
# The 900-th cell embedding
# The 901-th cell embedding
# The 902-th cell embedding
# The 903-th cell embedding
# The 904-th cell embedding
# The 905-th cell embedding
# The 906-th cell embedding
# The 907-th cell embedding
# The 908-th cell embedding
# The 909-th cell embedding
# The 910-th cell embedding
# The 911-th cell embedding
# The 912-th cell embedding
# The 913-th cell embedding
# The 914-th cell embedding
# The 915-th cell embedding
# The 916-th cell embedding
# The 917-th cell embedding
# The 918-th cell embedding
# The 919-th cell embedding
# The 920-th cell embedding
# The 921-th cell embedding
# The 922-th cell embedding
# The 923-th cell embedding
# The 924-th cell embedding
# The 925-th cell embedding
# The 926-th cell embedding
# The 927-th cell embedding
# The 928-th cell embedding
# The 929-th cell embedding
# The 930-th cell embedding
# The 931-th cell embedding
# The 932-th cell embedding
# The 933-th cell embedding
# The 934-th cell embedding
# The 935-th cell embedding
# The 936-th cell embedding
# The 937-th cell embedding
# The 938-th cell embedding
# The 939-th cell embedding
# The 940-th cell embedding
# The 941-th cell embedding
# The 942-th cell embedding
# The 943-th cell embedding
# The 944-th cell embedding
# The 945-th cell embedding
# The 946-th cell embedding
# The 947-th cell embedding
# The 948-th cell embedding
# The 949-th cell embedding
# The 950-th cell embedding
# The 951-th cell embedding
# The 952-th cell embedding
# The 953-th cell embedding
# The 954-th cell embedding
# The 955-th cell embedding
# The 956-th cell embedding
# The 957-th cell embedding
# The 958-th cell embedding
# The 959-th cell embedding
# The 960-th cell embedding
# The 961-th cell embedding
# The 962-th cell embedding
# The 963-th cell embedding
# The 964-th cell embedding
# The 965-th cell embedding
# The 966-th cell embedding
# The 967-th cell embedding
# The 968-th cell embedding
# The 969-th cell embedding
# The 970-th cell embedding
# The 971-th cell embedding
# The 972-th cell embedding
# The 973-th cell embedding
# The 974-th cell embedding
# The 975-th cell embedding
# The 976-th cell embedding
# The 977-th cell embedding
# The 978-th cell embedding
# The 979-th cell embedding
# The 980-th cell embedding
# The 981-th cell embedding
# The 982-th cell embedding
# The 983-th cell embedding
# The 984-th cell embedding
# The 985-th cell embedding
# The 986-th cell embedding
# The 987-th cell embedding
# The 988-th cell embedding
# The 989-th cell embedding
# The 990-th cell embedding
# The 991-th cell embedding
# The 992-th cell embedding
# The 993-th cell embedding
# The 994-th cell embedding
# The 995-th cell embedding
# The 996-th cell embedding
# The 997-th cell embedding
# The 998-th cell embedding
# The 999-th cell embedding
# The 1000-th cell embedding
# The 1001-th cell embedding
# The 1002-th cell embedding
# The 1003-th cell embedding
# The 1004-th cell embedding
# The 1005-th cell embedding
# The 1006-th cell embedding
# The 1007-th cell embedding
# The 1008-th cell embedding
# The 1009-th cell embedding
# The 1010-th cell embedding
# The 1011-th cell embedding
# The 1012-th cell embedding
# The 1013-th cell embedding
# The 1014-th cell embedding
# The 1015-th cell embedding
# The 1016-th cell embedding
# The 1017-th cell embedding
# The 1018-th cell embedding
# The 1019-th cell embedding
# The 1020-th cell embedding
# The 1021-th cell embedding
# The 1022-th cell embedding
# The 1023-th cell embedding
# The 1024-th cell embedding
# The 1025-th cell embedding
# The 1026-th cell embedding
# The 1027-th cell embedding
# The 1028-th cell embedding
# The 1029-th cell embedding
# The 1030-th cell embedding
# The 1031-th cell embedding
# The 1032-th cell embedding
# The 1033-th cell embedding
# The 1034-th cell embedding
# The 1035-th cell embedding
# The 1036-th cell embedding
# The 1037-th cell embedding
# The 1038-th cell embedding
# The 1039-th cell embedding
# The 1040-th cell embedding
# The 1041-th cell embedding
# The 1042-th cell embedding
# The 1043-th cell embedding
# The 1044-th cell embedding
# The 1045-th cell embedding
# The 1046-th cell embedding
# The 1047-th cell embedding
# The 1048-th cell embedding
# The 1049-th cell embedding
# The 1050-th cell embedding
# The 1051-th cell embedding
# The 1052-th cell embedding
# The 1053-th cell embedding
# The 1054-th cell embedding
# The 1055-th cell embedding
# The 1056-th cell embedding
# The 1057-th cell embedding
# The 1058-th cell embedding
# The 1059-th cell embedding
# The 1060-th cell embedding
# The 1061-th cell embedding
# The 1062-th cell embedding
# The 1063-th cell embedding
# The 1064-th cell embedding
# The 1065-th cell embedding
# The 1066-th cell embedding
# The 1067-th cell embedding
# The 1068-th cell embedding
# The 1069-th cell embedding
# The 1070-th cell embedding
# The 1071-th cell embedding
# The 1072-th cell embedding
# The 1073-th cell embedding
# The 1074-th cell embedding
# The 1075-th cell embedding
# The 1076-th cell embedding
# The 1077-th cell embedding
# The 1078-th cell embedding
# The 1079-th cell embedding
# The 1080-th cell embedding
# The 1081-th cell embedding
# The 1082-th cell embedding
# The 1083-th cell embedding
# The 1084-th cell embedding
# The 1085-th cell embedding
# The 1086-th cell embedding
# The 1087-th cell embedding
# The 1088-th cell embedding
# The 1089-th cell embedding
# The 1090-th cell embedding
# The 1091-th cell embedding
# The 1092-th cell embedding
# The 1093-th cell embedding
# The 1094-th cell embedding
# The 1095-th cell embedding
# The 1096-th cell embedding
# The 1097-th cell embedding
# The 1098-th cell embedding
# The 1099-th cell embedding
# The 1100-th cell embedding
# The 1101-th cell embedding
# The 1102-th cell embedding
# The 1103-th cell embedding
# The 1104-th cell embedding
# The 1105-th cell embedding
# The 1106-th cell embedding
# The 1107-th cell embedding
# The 1108-th cell embedding
# The 1109-th cell embedding
# The 1110-th cell embedding
# The 1111-th cell embedding
# The 1112-th cell embedding
# The 1113-th cell embedding
# The 1114-th cell embedding
# The 1115-th cell embedding
# The 1116-th cell embedding
# The 1117-th cell embedding
# The 1118-th cell embedding
# The 1119-th cell embedding
# The 1120-th cell embedding
# The 1121-th cell embedding
# The 1122-th cell embedding
# The 1123-th cell embedding
# The 1124-th cell embedding
# The 1125-th cell embedding
# The 1126-th cell embedding
# The 1127-th cell embedding
# The 1128-th cell embedding
# The 1129-th cell embedding
# The 1130-th cell embedding
# The 1131-th cell embedding
# The 1132-th cell embedding
# The 1133-th cell embedding
# The 1134-th cell embedding
# The 1135-th cell embedding
# The 1136-th cell embedding
# The 1137-th cell embedding
# The 1138-th cell embedding
# The 1139-th cell embedding
# The 1140-th cell embedding
# The 1141-th cell embedding
# The 1142-th cell embedding
# The 1143-th cell embedding
# The 1144-th cell embedding
# The 1145-th cell embedding
# The 1146-th cell embedding
# The 1147-th cell embedding
# The 1148-th cell embedding
# The 1149-th cell embedding
# The 1150-th cell embedding
# The 1151-th cell embedding
# The 1152-th cell embedding
# The 1153-th cell embedding
# The 1154-th cell embedding
# The 1155-th cell embedding
# The 1156-th cell embedding
# The 1157-th cell embedding
# The 1158-th cell embedding
# The 1159-th cell embedding
# The 1160-th cell embedding
# The 1161-th cell embedding
# The 1162-th cell embedding
# The 1163-th cell embedding
# The 1164-th cell embedding
# The 1165-th cell embedding
# The 1166-th cell embedding
# The 1167-th cell embedding
# The 1168-th cell embedding
# The 1169-th cell embedding
# The 1170-th cell embedding
# The 1171-th cell embedding
# The 1172-th cell embedding
# The 1173-th cell embedding
# The 1174-th cell embedding
# The 1175-th cell embedding
# The 1176-th cell embedding
# The 1177-th cell embedding
# The 1178-th cell embedding
# The 1179-th cell embedding
# The 1180-th cell embedding
# The 1181-th cell embedding
# The 1182-th cell embedding
# The 1183-th cell embedding
# The 1184-th cell embedding
# The 1185-th cell embedding
# The 1186-th cell embedding
# The 1187-th cell embedding
# The 1188-th cell embedding
# The 1189-th cell embedding
# The 1190-th cell embedding
# The 1191-th cell embedding
# The 1192-th cell embedding
# The 1193-th cell embedding
# The 1194-th cell embedding
# The 1195-th cell embedding
# The 1196-th cell embedding
# The 1197-th cell embedding
# The 1198-th cell embedding
# The 1199-th cell embedding
# The 1200-th cell embedding
# The 1201-th cell embedding
# The 1202-th cell embedding
# The 1203-th cell embedding
# The 1204-th cell embedding
# The 1205-th cell embedding
# The 1206-th cell embedding
# The 1207-th cell embedding
# The 1208-th cell embedding
# The 1209-th cell embedding
# The 1210-th cell embedding
# The 1211-th cell embedding
# The 1212-th cell embedding
# The 1213-th cell embedding
# The 1214-th cell embedding
# The 1215-th cell embedding
# The 1216-th cell embedding
# The 1217-th cell embedding
# The 1218-th cell embedding
# The 1219-th cell embedding
# The 1220-th cell embedding
# The 1221-th cell embedding
# The 1222-th cell embedding
# The 1223-th cell embedding
# The 1224-th cell embedding
# The 1225-th cell embedding
# The 1226-th cell embedding
# The 1227-th cell embedding
# The 1228-th cell embedding
# The 1229-th cell embedding
# The 1230-th cell embedding
# The 1231-th cell embedding
# The 1232-th cell embedding
# The 1233-th cell embedding
# The 1234-th cell embedding
# The 1235-th cell embedding
# The 1236-th cell embedding
# The 1237-th cell embedding
# The 1238-th cell embedding
# The 1239-th cell embedding
# The 1240-th cell embedding
# The 1241-th cell embedding
# The 1242-th cell embedding
# The 1243-th cell embedding
# The 1244-th cell embedding
# The 1245-th cell embedding
# The 1246-th cell embedding
# The 1247-th cell embedding
# The 1248-th cell embedding
# The 1249-th cell embedding
# The 1250-th cell embedding
# The 1251-th cell embedding
# The 1252-th cell embedding
# The 1253-th cell embedding
# The 1254-th cell embedding
# The 1255-th cell embedding
# The 1256-th cell embedding
# The 1257-th cell embedding
# The 1258-th cell embedding
# The 1259-th cell embedding
# The 1260-th cell embedding
# The 1261-th cell embedding
# The 1262-th cell embedding
# The 1263-th cell embedding
# The 1264-th cell embedding
# The 1265-th cell embedding
# The 1266-th cell embedding
# The 1267-th cell embedding
# The 1268-th cell embedding
# The 1269-th cell embedding
# The 1270-th cell embedding
# The 1271-th cell embedding
# The 1272-th cell embedding
# The 1273-th cell embedding
# The 1274-th cell embedding
# The 1275-th cell embedding
# The 1276-th cell embedding
# The 1277-th cell embedding
# The 1278-th cell embedding
# The 1279-th cell embedding
# The 1280-th cell embedding
# The 1281-th cell embedding
# The 1282-th cell embedding
# The 1283-th cell embedding
# The 1284-th cell embedding
# The 1285-th cell embedding
# The 1286-th cell embedding
# The 1287-th cell embedding
# The 1288-th cell embedding
# The 1289-th cell embedding
# The 1290-th cell embedding
# The 1291-th cell embedding
# The 1292-th cell embedding
# The 1293-th cell embedding
# The 1294-th cell embedding
# The 1295-th cell embedding
# The 1296-th cell embedding
# The 1297-th cell embedding
# The 1298-th cell embedding
# The 1299-th cell embedding
# The 1300-th cell embedding
# The 1301-th cell embedding
# The 1302-th cell embedding
# The 1303-th cell embedding
# The 1304-th cell embedding
# The 1305-th cell embedding
# The 1306-th cell embedding
# The 1307-th cell embedding
# The 1308-th cell embedding
# The 1309-th cell embedding
# The 1310-th cell embedding
# The 1311-th cell embedding
# The 1312-th cell embedding
# The 1313-th cell embedding
# The 1314-th cell embedding
# The 1315-th cell embedding
# The 1316-th cell embedding
# The 1317-th cell embedding
# The 1318-th cell embedding
# The 1319-th cell embedding
# The 1320-th cell embedding
# The 1321-th cell embedding
# The 1322-th cell embedding
# The 1323-th cell embedding
# The 1324-th cell embedding
# The 1325-th cell embedding
# The 1326-th cell embedding
# The 1327-th cell embedding
# The 1328-th cell embedding
# The 1329-th cell embedding
# The 1330-th cell embedding
# The 1331-th cell embedding
# The 1332-th cell embedding
# The 1333-th cell embedding
# The 1334-th cell embedding
# The 1335-th cell embedding
# The 1336-th cell embedding
# The 1337-th cell embedding
# The 1338-th cell embedding
# The 1339-th cell embedding
# The 1340-th cell embedding
# The 1341-th cell embedding
# The 1342-th cell embedding
# The 1343-th cell embedding
# The 1344-th cell embedding
# The 1345-th cell embedding
# The 1346-th cell embedding
# The 1347-th cell embedding
# The 1348-th cell embedding
# The 1349-th cell embedding
# The 1350-th cell embedding
# The 1351-th cell embedding
# The 1352-th cell embedding
# The 1353-th cell embedding
# The 1354-th cell embedding
# The 1355-th cell embedding
# The 1356-th cell embedding
# The 1357-th cell embedding
# The 1358-th cell embedding
# The 1359-th cell embedding
# The 1360-th cell embedding
# The 1361-th cell embedding
# The 1362-th cell embedding
# The 1363-th cell embedding
# The 1364-th cell embedding
# The 1365-th cell embedding
# The 1366-th cell embedding
# The 1367-th cell embedding
# The 1368-th cell embedding
# The 1369-th cell embedding
# The 1370-th cell embedding
# The 1371-th cell embedding
# The 1372-th cell embedding
# The 1373-th cell embedding
# The 1374-th cell embedding
# The 1375-th cell embedding
# The 1376-th cell embedding
# The 1377-th cell embedding
# The 1378-th cell embedding
# The 1379-th cell embedding
# The 1380-th cell embedding
# The 1381-th cell embedding
# The 1382-th cell embedding
# The 1383-th cell embedding
# The 1384-th cell embedding
# The 1385-th cell embedding
# The 1386-th cell embedding
# The 1387-th cell embedding
# The 1388-th cell embedding
# The 1389-th cell embedding
# The 1390-th cell embedding
# The 1391-th cell embedding
# The 1392-th cell embedding
# The 1393-th cell embedding
# The 1394-th cell embedding
# The 1395-th cell embedding
# The 1396-th cell embedding
# The 1397-th cell embedding
# The 1398-th cell embedding
# The 1399-th cell embedding
# The 1400-th cell embedding
# The 1401-th cell embedding
# The 1402-th cell embedding
# The 1403-th cell embedding
# The 1404-th cell embedding
# The 1405-th cell embedding
# The 1406-th cell embedding
# The 1407-th cell embedding
# The 1408-th cell embedding
# The 1409-th cell embedding
# The 1410-th cell embedding
# The 1411-th cell embedding
# The 1412-th cell embedding
# The 1413-th cell embedding
# The 1414-th cell embedding
# The 1415-th cell embedding
# The 1416-th cell embedding
# The 1417-th cell embedding
# The 1418-th cell embedding
# The 1419-th cell embedding
# The 1420-th cell embedding
# The 1421-th cell embedding
# The 1422-th cell embedding
# The 1423-th cell embedding
# The 1424-th cell embedding
# The 1425-th cell embedding
# The 1426-th cell embedding
# The 1427-th cell embedding
# The 1428-th cell embedding
# The 1429-th cell embedding
# The 1430-th cell embedding
# The 1431-th cell embedding
# The 1432-th cell embedding
# The 1433-th cell embedding
# The 1434-th cell embedding
# The 1435-th cell embedding
# The 1436-th cell embedding
# The 1437-th cell embedding
# The 1438-th cell embedding
# The 1439-th cell embedding
# The 1440-th cell embedding
# The 1441-th cell embedding
# The 1442-th cell embedding
# The 1443-th cell embedding
# The 1444-th cell embedding
# The 1445-th cell embedding
# The 1446-th cell embedding
# The 1447-th cell embedding
# The 1448-th cell embedding
# The 1449-th cell embedding
# The 1450-th cell embedding
# The 1451-th cell embedding
# The 1452-th cell embedding
# The 1453-th cell embedding
# The 1454-th cell embedding
# The 1455-th cell embedding
# The 1456-th cell embedding
# The 1457-th cell embedding
# The 1458-th cell embedding
# The 1459-th cell embedding
# The 1460-th cell embedding
# The 1461-th cell embedding
# The 1462-th cell embedding
# The 1463-th cell embedding
# The 1464-th cell embedding
# The 1465-th cell embedding
# The 1466-th cell embedding
# The 1467-th cell embedding
# The 1468-th cell embedding
# The 1469-th cell embedding
# The 1470-th cell embedding
# The 1471-th cell embedding
# The 1472-th cell embedding
# The 1473-th cell embedding
# The 1474-th cell embedding
# The 1475-th cell embedding
# The 1476-th cell embedding
# The 1477-th cell embedding
# The 1478-th cell embedding
# The 1479-th cell embedding
# The 1480-th cell embedding
# The 1481-th cell embedding
# The 1482-th cell embedding
# The 1483-th cell embedding
# The 1484-th cell embedding
# The 1485-th cell embedding
# The 1486-th cell embedding
# The 1487-th cell embedding
# The 1488-th cell embedding
# The 1489-th cell embedding
# The 1490-th cell embedding
# The 1491-th cell embedding
# The 1492-th cell embedding
# The 1493-th cell embedding
# The 1494-th cell embedding
# The 1495-th cell embedding
# The 1496-th cell embedding
# The 1497-th cell embedding
# The 1498-th cell embedding
# The 1499-th cell embedding
# The 1500-th cell embedding
# The 1501-th cell embedding
# The 1502-th cell embedding
# The 1503-th cell embedding
# The 1504-th cell embedding
# The 1505-th cell embedding
# The 1506-th cell embedding
# The 1507-th cell embedding
# The 1508-th cell embedding
# The 1509-th cell embedding
# The 1510-th cell embedding
# The 1511-th cell embedding
# The 1512-th cell embedding
# The 1513-th cell embedding
# The 1514-th cell embedding
# The 1515-th cell embedding
# The 1516-th cell embedding
# The 1517-th cell embedding
# The 1518-th cell embedding
# The 1519-th cell embedding
# The 1520-th cell embedding
# The 1521-th cell embedding
# The 1522-th cell embedding
# The 1523-th cell embedding
# The 1524-th cell embedding
# The 1525-th cell embedding
# The 1526-th cell embedding
# The 1527-th cell embedding
# The 1528-th cell embedding
# The 1529-th cell embedding
# The 1530-th cell embedding
# The 1531-th cell embedding
# The 1532-th cell embedding
# The 1533-th cell embedding
# The 1534-th cell embedding
# The 1535-th cell embedding
# The 1536-th cell embedding
# The 1537-th cell embedding
# The 1538-th cell embedding
# The 1539-th cell embedding
# The 1540-th cell embedding
# The 1541-th cell embedding
# The 1542-th cell embedding
# The 1543-th cell embedding
# The 1544-th cell embedding
# The 1545-th cell embedding
# The 1546-th cell embedding
# The 1547-th cell embedding
# The 1548-th cell embedding
# The 1549-th cell embedding
# The 1550-th cell embedding
# The 1551-th cell embedding
# The 1552-th cell embedding
# The 1553-th cell embedding
# The 1554-th cell embedding
# The 1555-th cell embedding
# The 1556-th cell embedding
# The 1557-th cell embedding
# The 1558-th cell embedding
# The 1559-th cell embedding
# The 1560-th cell embedding
# The 1561-th cell embedding
# The 1562-th cell embedding
# The 1563-th cell embedding
# The 1564-th cell embedding
# The 1565-th cell embedding
# The 1566-th cell embedding
# The 1567-th cell embedding
# The 1568-th cell embedding
# The 1569-th cell embedding
# The 1570-th cell embedding
# The 1571-th cell embedding
# The 1572-th cell embedding
# The 1573-th cell embedding
# The 1574-th cell embedding
# The 1575-th cell embedding
# The 1576-th cell embedding
# The 1577-th cell embedding
# The 1578-th cell embedding
# The 1579-th cell embedding
# The 1580-th cell embedding
# The 1581-th cell embedding
# The 1582-th cell embedding
# The 1583-th cell embedding
# The 1584-th cell embedding
# The 1585-th cell embedding
# The 1586-th cell embedding
# The 1587-th cell embedding
# The 1588-th cell embedding
# The 1589-th cell embedding
# The 1590-th cell embedding
# The 1591-th cell embedding
# The 1592-th cell embedding
# The 1593-th cell embedding
# The 1594-th cell embedding
# The 1595-th cell embedding
# The 1596-th cell embedding
# The 1597-th cell embedding
# The 1598-th cell embedding
# The 1599-th cell embedding
# The 1600-th cell embedding
# The 1601-th cell embedding
# The 1602-th cell embedding
# The 1603-th cell embedding
# The 1604-th cell embedding
# The 1605-th cell embedding
# The 1606-th cell embedding
# The 1607-th cell embedding
# The 1608-th cell embedding
# The 1609-th cell embedding
# The 1610-th cell embedding
# The 1611-th cell embedding
# The 1612-th cell embedding
# The 1613-th cell embedding
# The 1614-th cell embedding
# The 1615-th cell embedding
# The 1616-th cell embedding
# The 1617-th cell embedding
# The 1618-th cell embedding
# The 1619-th cell embedding
# The 1620-th cell embedding
# The 1621-th cell embedding
# The 1622-th cell embedding
# The 1623-th cell embedding
# The 1624-th cell embedding
# The 1625-th cell embedding
# The 1626-th cell embedding
# The 1627-th cell embedding
# The 1628-th cell embedding
# The 1629-th cell embedding
# The 1630-th cell embedding
# The 1631-th cell embedding
# The 1632-th cell embedding
# The 1633-th cell embedding
# The 1634-th cell embedding
# The 1635-th cell embedding
# The 1636-th cell embedding
# The 1637-th cell embedding
# The 1638-th cell embedding
# The 1639-th cell embedding
# The 1640-th cell embedding
# The 1641-th cell embedding
# The 1642-th cell embedding
# The 1643-th cell embedding
# The 1644-th cell embedding
# The 1645-th cell embedding
# The 1646-th cell embedding
# The 1647-th cell embedding
# The 1648-th cell embedding
# The 1649-th cell embedding
# The 1650-th cell embedding
# The 1651-th cell embedding
# The 1652-th cell embedding
# The 1653-th cell embedding
# The 1654-th cell embedding
# The 1655-th cell embedding
# The 1656-th cell embedding
# The 1657-th cell embedding
# The 1658-th cell embedding
# The 1659-th cell embedding
# The 1660-th cell embedding
# The 1661-th cell embedding
# The 1662-th cell embedding
# The 1663-th cell embedding
# The 1664-th cell embedding
# The 1665-th cell embedding
# The 1666-th cell embedding
# The 1667-th cell embedding
# The 1668-th cell embedding
# The 1669-th cell embedding
# The 1670-th cell embedding
# The 1671-th cell embedding
# The 1672-th cell embedding
# The 1673-th cell embedding
# The 1674-th cell embedding
# The 1675-th cell embedding
# The 1676-th cell embedding
# The 1677-th cell embedding
# The 1678-th cell embedding
# The 1679-th cell embedding
# The 1680-th cell embedding
# The 1681-th cell embedding
# The 1682-th cell embedding
# The 1683-th cell embedding
# The 1684-th cell embedding
# The 1685-th cell embedding
# The 1686-th cell embedding
# The 1687-th cell embedding
# The 1688-th cell embedding
# The 1689-th cell embedding
# The 1690-th cell embedding
# The 1691-th cell embedding
# The 1692-th cell embedding
# The 1693-th cell embedding
# The 1694-th cell embedding
# The 1695-th cell embedding
# The 1696-th cell embedding
# The 1697-th cell embedding
# The 1698-th cell embedding
# The 1699-th cell embedding
# The 1700-th cell embedding
# The 1701-th cell embedding
# The 1702-th cell embedding
# The 1703-th cell embedding
# The 1704-th cell embedding
# The 1705-th cell embedding
# The 1706-th cell embedding
# The 1707-th cell embedding
# The 1708-th cell embedding
# The 1709-th cell embedding
# The 1710-th cell embedding
# The 1711-th cell embedding
# The 1712-th cell embedding
# The 1713-th cell embedding
# The 1714-th cell embedding
# The 1715-th cell embedding
# The 1716-th cell embedding
# The 1717-th cell embedding
# The 1718-th cell embedding
# The 1719-th cell embedding
# The 1720-th cell embedding
# The 1721-th cell embedding
# The 1722-th cell embedding
# The 1723-th cell embedding
# The 1724-th cell embedding
# The 1725-th cell embedding
# The 1726-th cell embedding
# The 1727-th cell embedding
# The 1728-th cell embedding
# The 1729-th cell embedding
# The 1730-th cell embedding
# The 1731-th cell embedding
# The 1732-th cell embedding
# The 1733-th cell embedding
# The 1734-th cell embedding
# The 1735-th cell embedding
# The 1736-th cell embedding
# The 1737-th cell embedding
# The 1738-th cell embedding
# The 1739-th cell embedding
# The 1740-th cell embedding
# The 1741-th cell embedding
# The 1742-th cell embedding
# The 1743-th cell embedding
# The 1744-th cell embedding
# The 1745-th cell embedding
# The 1746-th cell embedding
# The 1747-th cell embedding
# The 1748-th cell embedding
# The 1749-th cell embedding
# The 1750-th cell embedding
# The 1751-th cell embedding
# The 1752-th cell embedding
# The 1753-th cell embedding
# The 1754-th cell embedding
# The 1755-th cell embedding
# The 1756-th cell embedding
# The 1757-th cell embedding
# The 1758-th cell embedding
# The 1759-th cell embedding
# The 1760-th cell embedding
# The 1761-th cell embedding
# The 1762-th cell embedding
# The 1763-th cell embedding
# The 1764-th cell embedding
# The 1765-th cell embedding
# The 1766-th cell embedding
# The 1767-th cell embedding
# The 1768-th cell embedding
# The 1769-th cell embedding
# The 1770-th cell embedding
# The 1771-th cell embedding
# The 1772-th cell embedding
# The 1773-th cell embedding
# The 1774-th cell embedding
# The 1775-th cell embedding
# The 1776-th cell embedding
# The 1777-th cell embedding
# The 1778-th cell embedding
# The 1779-th cell embedding
# The 1780-th cell embedding
# The 1781-th cell embedding
# The 1782-th cell embedding
# The 1783-th cell embedding
# The 1784-th cell embedding
# The 1785-th cell embedding
# The 1786-th cell embedding
# The 1787-th cell embedding
# The 1788-th cell embedding
# The 1789-th cell embedding
# The 1790-th cell embedding
# The 1791-th cell embedding
# The 1792-th cell embedding
# The 1793-th cell embedding
# The 1794-th cell embedding
# The 1795-th cell embedding
# The 1796-th cell embedding
# The 1797-th cell embedding
# The 1798-th cell embedding
# The 1799-th cell embedding
# The 1800-th cell embedding
# The 1801-th cell embedding
# The 1802-th cell embedding
# The 1803-th cell embedding
# The 1804-th cell embedding
# The 1805-th cell embedding
# The 1806-th cell embedding
# The 1807-th cell embedding
# The 1808-th cell embedding
# The 1809-th cell embedding
# The 1810-th cell embedding
# The 1811-th cell embedding
# The 1812-th cell embedding
# The 1813-th cell embedding
# The 1814-th cell embedding
# The 1815-th cell embedding
# ...
# The 2407-th cell embedding
# The 2408-th cell embedding
# The 2409-th cell embedding
# The 2410-th cell embedding
# The 2411-th cell embedding
# The 2412-th cell embedding
# The 2413-th cell embedding
# The 2414-th cell embedding
# The 2415-th cell embedding
# The 2416-th cell embedding
# The 2417-th cell embedding
# The 2418-th cell embedding
# The 2419-th cell embedding
# The 2420-th cell embedding
# The 2421-th cell embedding
# The 2422-th cell embedding
# The 2423-th cell embedding
# The 2424-th cell embedding
# The 2425-th cell embedding
# The 2426-th cell embedding
# The 2427-th cell embedding
# The 2428-th cell embedding
# The 2429-th cell embedding
# The 2430-th cell embedding
# The 2431-th cell embedding
# The 2432-th cell embedding
# The 2433-th cell embedding
# The 2434-th cell embedding
# The 2435-th cell embedding
# The 2436-th cell embedding
# The 2437-th cell embedding
# The 2438-th cell embedding
# The 2439-th cell embedding
# The 2440-th cell embedding
# The 2441-th cell embedding
# The 2442-th cell embedding
# The 2443-th cell embedding
# The 2444-th cell embedding
# The 2445-th cell embedding
# The 2446-th cell embedding
# The 2447-th cell embedding
# The 2448-th cell embedding
# The 2449-th cell embedding
# The 2450-th cell embedding
# The 2451-th cell embedding
# The 2452-th cell embedding
# The 2453-th cell embedding
# The 2454-th cell embedding
# The 2455-th cell embedding
# The 2456-th cell embedding
# The 2457-th cell embedding
# The 2458-th cell embedding
# The 2459-th cell embedding
# The 2460-th cell embedding
# The 2461-th cell embedding
# The 2462-th cell embedding
# The 2463-th cell embedding
# The 2464-th cell embedding
# The 2465-th cell embedding
# The 2466-th cell embedding
# The 2467-th cell embedding
# The 2468-th cell embedding
# The 2469-th cell embedding
# The 2470-th cell embedding
# The 2471-th cell embedding
# The 2472-th cell embedding
# The 2473-th cell embedding
# The 2474-th cell embedding
# The 2475-th cell embedding
# The 2476-th cell embedding
# The 2477-th cell embedding
# The 2478-th cell embedding
# The 2479-th cell embedding
# The 2480-th cell embedding
# The 2481-th cell embedding
# The 2482-th cell embedding
# The 2483-th cell embedding
# The 2484-th cell embedding
# The 2485-th cell embedding
# The 2486-th cell embedding
# The 2487-th cell embedding
# The 2488-th cell embedding
# The 2489-th cell embedding
# The 2490-th cell embedding
# The 2491-th cell embedding
# The 2492-th cell embedding
# The 2493-th cell embedding
# The 2494-th cell embedding
# The 2495-th cell embedding
# The 2496-th cell embedding
# The 2497-th cell embedding
# The 2498-th cell embedding
# The 2499-th cell embedding
# The 2500-th cell embedding
# The 2501-th cell embedding
# The 2502-th cell embedding
# The 2503-th cell embedding
# The 2504-th cell embedding
# The 2505-th cell embedding
# The 2506-th cell embedding
# The 2507-th cell embedding
# The 2508-th cell embedding
# The 2509-th cell embedding
# The 2510-th cell embedding
# The 2511-th cell embedding
# The 2512-th cell embedding
# The 2513-th cell embedding
# The 2514-th cell embedding
# The 2515-th cell embedding
# The 2516-th cell embedding
# The 2517-th cell embedding
# The 2518-th cell embedding
# The 2519-th cell embedding
# The 2520-th cell embedding
# The 2521-th cell embedding
# The 2522-th cell embedding
# The 2523-th cell embedding
# The 2524-th cell embedding
# The 2525-th cell embedding
# The 2526-th cell embedding
# The 2527-th cell embedding
# The 2528-th cell embedding
# The 2529-th cell embedding
# The 2530-th cell embedding
# The 2531-th cell embedding
# The 2532-th cell embedding
# The 2533-th cell embedding
# The 2534-th cell embedding
# The 2535-th cell embedding
# The 2536-th cell embedding
# The 2537-th cell embedding
# The 2538-th cell embedding
# The 2539-th cell embedding
# The 2540-th cell embedding
# The 2541-th cell embedding
# The 2542-th cell embedding
# The 2543-th cell embedding
# The 2544-th cell embedding
# The 2545-th cell embedding
# The 2546-th cell embedding
# The 2547-th cell embedding
# The 2548-th cell embedding
# The 2549-th cell embedding
# The 2550-th cell embedding
# The 2551-th cell embedding
# The 2552-th cell embedding
# The 2553-th cell embedding
# The 2554-th cell embedding
# The 2555-th cell embedding
# The 2556-th cell embedding
# The 2557-th cell embedding
# The 2558-th cell embedding
# The 2559-th cell embedding
# The 2560-th cell embedding
# The 2561-th cell embedding
# The 2562-th cell embedding
# The 2563-th cell embedding
# The 2564-th cell embedding
# The 2565-th cell embedding
# The 2566-th cell embedding
# The 2567-th cell embedding
# The 2568-th cell embedding
# The 2569-th cell embedding
# The 2570-th cell embedding
# The 2571-th cell embedding
# The 2572-th cell embedding
# The 2573-th cell embedding
# The 2574-th cell embedding
# The 2575-th cell embedding
# The 2576-th cell embedding
# The 2577-th cell embedding
# The 2578-th cell embedding
# The 2579-th cell embedding
# The 2580-th cell embedding
# The 2581-th cell embedding
# The 2582-th cell embedding
# The 2583-th cell embedding
# The 2584-th cell embedding
# The 2585-th cell embedding
# The 2586-th cell embedding
# The 2587-th cell embedding
# The 2588-th cell embedding
# The 2589-th cell embedding
# The 2590-th cell embedding
# The 2591-th cell embedding
# The 2592-th cell embedding
# The 2593-th cell embedding
# The 2594-th cell embedding
# The 2595-th cell embedding
# The 2596-th cell embedding
# The 2597-th cell embedding
# The 2598-th cell embedding
# The 2599-th cell embedding
# The 2600-th cell embedding
# The 2601-th cell embedding
# The 2602-th cell embedding
# The 2603-th cell embedding
# The 2604-th cell embedding
# The 2605-th cell embedding
# The 2606-th cell embedding
# The 2607-th cell embedding
# The 2608-th cell embedding
# The 2609-th cell embedding
# The 2610-th cell embedding
# The 2611-th cell embedding
# The 2612-th cell embedding
# The 2613-th cell embedding
# The 2614-th cell embedding
# The 2615-th cell embedding
# The 2616-th cell embedding
# The 2617-th cell embedding
# The 2618-th cell embedding
# The 2619-th cell embedding
# The 2620-th cell embedding
# The 2621-th cell embedding
# The 2622-th cell embedding
# The 2623-th cell embedding
# The 2624-th cell embedding
# The 2625-th cell embedding
# The 2626-th cell embedding
# The 2627-th cell embedding
# The 2628-th cell embedding
# The 2629-th cell embedding
# The 2630-th cell embedding
# The 2631-th cell embedding
# The 2632-th cell embedding
# The 2633-th cell embedding
# The 2634-th cell embedding
# The 2635-th cell embedding
# The 2636-th cell embedding
# The 2637-th cell embedding
# The 2638-th cell embedding
# The 2639-th cell embedding
# The 2640-th cell embedding
# The 2641-th cell embedding
# The 2642-th cell embedding
# The 2643-th cell embedding
# The 2644-th cell embedding
# The 2645-th cell embedding
# The 2646-th cell embedding
# The 2647-th cell embedding
# The 2648-th cell embedding
# The 2649-th cell embedding
# The 2650-th cell embedding
# The 2651-th cell embedding
# The 2652-th cell embedding
# The 2653-th cell embedding
# The 2654-th cell embedding
# The 2655-th cell embedding
# The 2656-th cell embedding
# The 2657-th cell embedding
# The 2658-th cell embedding
# The 2659-th cell embedding
# The 2660-th cell embedding
# The 2661-th cell embedding
# The 2662-th cell embedding
# The 2663-th cell embedding
# The 2664-th cell embedding
# The 2665-th cell embedding
# The 2666-th cell embedding
# The 2667-th cell embedding
# The 2668-th cell embedding
# The 2669-th cell embedding
# The 2670-th cell embedding
# The 2671-th cell embedding
# The 2672-th cell embedding
# The 2673-th cell embedding
# The 2674-th cell embedding
# The 2675-th cell embedding
# The 2676-th cell embedding
# The 2677-th cell embedding
# The 2678-th cell embedding
# The 2679-th cell embedding
# The 2680-th cell embedding
# The 2681-th cell embedding
# The 2682-th cell embedding
# The 2683-th cell embedding
# The 2684-th cell embedding
# The 2685-th cell embedding
# The 2686-th cell embedding
# The 2687-th cell embedding
# The 2688-th cell embedding
# The 2689-th cell embedding
# The 2690-th cell embedding
# The 2691-th cell embedding
# The 2692-th cell embedding
# The 2693-th cell embedding
# The 2694-th cell embedding
# The 2695-th cell embedding
# The 2696-th cell embedding
# The 2697-th cell embedding
# The 2698-th cell embedding
# The 2699-th cell embedding
# The 2700-th cell embedding
# The 2701-th cell embedding
# The 2702-th cell embedding
# The 2703-th cell embedding
# The 2704-th cell embedding
# The 2705-th cell embedding
# The 2706-th cell embedding
# The 2707-th cell embedding
# The 2708-th cell embedding
# The 2709-th cell embedding
# The 2710-th cell embedding
# The 2711-th cell embedding
# The 2712-th cell embedding
# The 2713-th cell embedding
# The 2714-th cell embedding
# The 2715-th cell embedding
# The 2716-th cell embedding
# The 2717-th cell embedding
# The 2718-th cell embedding
# The 2719-th cell embedding
# The 2720-th cell embedding
# The 2721-th cell embedding
# The 2722-th cell embedding
# The 2723-th cell embedding
# The 2724-th cell embedding
# The 2725-th cell embedding
# The 2726-th cell embedding
# The 2727-th cell embedding
# The 2728-th cell embedding
# The 2729-th cell embedding
# The 2730-th cell embedding
# The 2731-th cell embedding
# The 2732-th cell embedding
# The 2733-th cell embedding
# The 2734-th cell embedding
# The 2735-th cell embedding
# The 2736-th cell embedding
# The 2737-th cell embedding
# The 2738-th cell embedding
# The 2739-th cell embedding
# The 2740-th cell embedding
# The 2741-th cell embedding
# The 2742-th cell embedding
# The 2743-th cell embedding
# The 2744-th cell embedding
# The 2745-th cell embedding
# The 2746-th cell embedding
# The 2747-th cell embedding
# The 2748-th cell embedding
# The 2749-th cell embedding
# The 2750-th cell embedding
# The 2751-th cell embedding
# The 2752-th cell embedding
# The 2753-th cell embedding
# The 2754-th cell embedding
# The 2755-th cell embedding
# The 2756-th cell embedding
# The 2757-th cell embedding
# The 2758-th cell embedding
# The 2759-th cell embedding
# The 2760-th cell embedding
# The 2761-th cell embedding
# The 2762-th cell embedding
# The 2763-th cell embedding
# The 2764-th cell embedding
# The 2765-th cell embedding
# The 2766-th cell embedding
# The 2767-th cell embedding
# The 2768-th cell embedding
# The 2769-th cell embedding
# The 2770-th cell embedding
# The 2771-th cell embedding
# The 2772-th cell embedding
# The 2773-th cell embedding
# The 2774-th cell embedding
# The 2775-th cell embedding
# The 2776-th cell embedding
# The 2777-th cell embedding
# The 2778-th cell embedding
# The 2779-th cell embedding
# The 2780-th cell embedding
# The 2781-th cell embedding
# The 2782-th cell embedding
# The 2783-th cell embedding
# The 2784-th cell embedding
# The 2785-th cell embedding
# The 2786-th cell embedding
# The 2787-th cell embedding
# The 2788-th cell embedding
# The 2789-th cell embedding
# The 2790-th cell embedding
# The 2791-th cell embedding
# The 2792-th cell embedding
# The 2793-th cell embedding
# The 2794-th cell embedding
# The 2795-th cell embedding
# The 2796-th cell embedding
# The 2797-th cell embedding
# The 2798-th cell embedding
# The 2799-th cell embedding
# The 2800-th cell embedding
# The 2801-th cell embedding
# The 2802-th cell embedding
# The 2803-th cell embedding
# The 2804-th cell embedding
# The 2805-th cell embedding
# The 2806-th cell embedding
# The 2807-th cell embedding
# The 2808-th cell embedding
# The 2809-th cell embedding
# The 2810-th cell embedding
# The 2811-th cell embedding
# The 2812-th cell embedding
# The 2813-th cell embedding
# The 2814-th cell embedding
# The 2815-th cell embedding
# The 2816-th cell embedding
# The 2817-th cell embedding
# The 2818-th cell embedding
# The 2819-th cell embedding
# The 2820-th cell embedding
# The 2821-th cell embedding
# The 2822-th cell embedding
# The 2823-th cell embedding
# The 2824-th cell embedding
# The 2825-th cell embedding
# The 2826-th cell embedding
# The 2827-th cell embedding
# The 2828-th cell embedding
# The 2829-th cell embedding
# The 2830-th cell embedding
# The 2831-th cell embedding
# The 2832-th cell embedding
# The 2833-th cell embedding
# The 2834-th cell embedding
# The 2835-th cell embedding
# The 2836-th cell embedding
# The 2837-th cell embedding
# The 2838-th cell embedding
# The 2839-th cell embedding
# The 2840-th cell embedding
# The 2841-th cell embedding
# The 2842-th cell embedding
# The 2843-th cell embedding
# The 2844-th cell embedding
# The 2845-th cell embedding
# The 2846-th cell embedding
# The 2847-th cell embedding
# The 2848-th cell embedding
# The 2849-th cell embedding
# The 2850-th cell embedding
# The 2851-th cell embedding
# The 2852-th cell embedding
# The 2853-th cell embedding
# The 2854-th cell embedding
# The 2855-th cell embedding
# The 2856-th cell embedding
# The 2857-th cell embedding
# The 2858-th cell embedding
# The 2859-th cell embedding
# The 2860-th cell embedding
# The 2861-th cell embedding
# The 2862-th cell embedding
# The 2863-th cell embedding
# The 2864-th cell embedding
# The 2865-th cell embedding
# The 2866-th cell embedding
# The 2867-th cell embedding
# The 2868-th cell embedding
# The 2869-th cell embedding
# The 2870-th cell embedding
# The 2871-th cell embedding
# The 2872-th cell embedding
# The 2873-th cell embedding
# The 2874-th cell embedding
# The 2875-th cell embedding
# The 2876-th cell embedding
# The 2877-th cell embedding
# The 2878-th cell embedding
# The 2879-th cell embedding
# The 2880-th cell embedding
# The 2881-th cell embedding
# The 2882-th cell embedding
# The 2883-th cell embedding
# The 2884-th cell embedding
# The 2885-th cell embedding
# The 2886-th cell embedding
# The 2887-th cell embedding
# The 2888-th cell embedding
# The 2889-th cell embedding
# The 2890-th cell embedding
# The 2891-th cell embedding
# The 2892-th cell embedding
# The 2893-th cell embedding
# The 2894-th cell embedding
# The 2895-th cell embedding
# The 2896-th cell embedding
# The 2897-th cell embedding
# The 2898-th cell embedding
# The 2899-th cell embedding
# The 2900-th cell embedding
# The 2901-th cell embedding
# The 2902-th cell embedding
# The 2903-th cell embedding
# The 2904-th cell embedding
# The 2905-th cell embedding
# The 2906-th cell embedding
# The 2907-th cell embedding
# The 2908-th cell embedding
# The 2909-th cell embedding
# The 2910-th cell embedding
# The 2911-th cell embedding
# The 2912-th cell embedding
# The 2913-th cell embedding
# The 2914-th cell embedding
# The 2915-th cell embedding
# The 2916-th cell embedding
# The 2917-th cell embedding
# The 2918-th cell embedding
# The 2919-th cell embedding
# The 2920-th cell embedding
# The 2921-th cell embedding
# The 2922-th cell embedding
# The 2923-th cell embedding
# The 2924-th cell embedding
# The 2925-th cell embedding
# The 2926-th cell embedding
# The 2927-th cell embedding
# The 2928-th cell embedding
# The 2929-th cell embedding
# The 2930-th cell embedding
# The 2931-th cell embedding
# The 2932-th cell embedding
# The 2933-th cell embedding
# The 2934-th cell embedding
# The 2935-th cell embedding
# The 2936-th cell embedding
# The 2937-th cell embedding
# The 2938-th cell embedding
# The 2939-th cell embedding
# The 2940-th cell embedding
# The 2941-th cell embedding
# The 2942-th cell embedding
# The 2943-th cell embedding
# The 2944-th cell embedding
# The 2945-th cell embedding
# The 2946-th cell embedding
# The 2947-th cell embedding
# The 2948-th cell embedding
# The 2949-th cell embedding
# The 2950-th cell embedding
# The 2951-th cell embedding
# The 2952-th cell embedding
# The 2953-th cell embedding
# The 2954-th cell embedding
# The 2955-th cell embedding
# The 2956-th cell embedding
# The 2957-th cell embedding
# The 2958-th cell embedding
# The 2959-th cell embedding
# The 2960-th cell embedding
# The 2961-th cell embedding
# The 2962-th cell embedding
# The 2963-th cell embedding
# The 2964-th cell embedding
# The 2965-th cell embedding
# The 2966-th cell embedding
# The 2967-th cell embedding
# The 2968-th cell embedding
# The 2969-th cell embedding
# The 2970-th cell embedding
# The 2971-th cell embedding
# The 2972-th cell embedding
# The 2973-th cell embedding
# The 2974-th cell embedding
# The 2975-th cell embedding
# The 2976-th cell embedding
# The 2977-th cell embedding
# The 2978-th cell embedding
# The 2979-th cell embedding
# The 2980-th cell embedding
# The 2981-th cell embedding
# The 2982-th cell embedding
# The 2983-th cell embedding
# The 2984-th cell embedding
# The 2985-th cell embedding
# The 2986-th cell embedding
# The 2987-th cell embedding
# The 2988-th cell embedding
# The 2989-th cell embedding
# The 2990-th cell embedding
# The 2991-th cell embedding
# The 2992-th cell embedding
# The 2993-th cell embedding
# The 2994-th cell embedding
# The 2995-th cell embedding
# The 2996-th cell embedding
# The 2997-th cell embedding
# The 2998-th cell embedding

# %%
np.savetxt(dir + 'Fusion_sum-expr-scpsd-scgnn-pca.txt.gz', Fusion_sum)
np.savetxt(dir + 'Fusion_hadamard-expr-scpsd-scgnn-pca.txt.gz', Fusion_hadamard)
np.savetxt(dir + 'Fusion_attention-expr-scpsd-scgnn-pca.txt.gz', Fusion_attention)

np.savetxt(dir + 'Fusion_moe-expr-scpsd-scgnn-pca.txt.gz', np.array([fused_moe.detach().numpy().flatten() for fused_moe in Fused_moe]))
np.savetxt(dir + 'Fusion_residual-expr-scpsd-scgnn-pca.txt.gz', np.array([fused_residual.detach().numpy().flatten() for fused_residual in Fused_residual]))
np.savetxt(dir + 'Fusion_transformer-expr-scpsd-scgnn-pca.txt.gz', np.array([fused_transformer.detach().numpy().flatten() for fused_transformer in Fused_transformer]))
    
feature5 = Fusion_sum
feature6 = Fusion_hadamard
feature7 = Fusion_attention
feature8 = np.array([fused_moe.detach().numpy().flatten() for fused_moe in Fused_moe])
feature9 = np.array([fused_residual.detach().numpy().flatten() for fused_residual in Fused_residual])
feature10 = np.array([fused_transformer.detach().numpy().flatten() for fused_transformer in Fused_transformer])

# %%
print('Cross Fusion complete.')
# Out:
# Cross Fusion complete.

# %%
####        Step 4: Classification Module        ########################################################
unique_classes, counts = np.unique(Y, return_counts=True)
min_count = 3
for cls in unique_classes:
    if counts[cls] < min_count:
        Y[Y == cls] = max(unique_classes) + 1 
new_label_encoder = LabelEncoder()
y = new_label_encoder.fit_transform(Y)

model = get_model(model_name)

# %%
results1 = cross_validation_model(feature1, y, model)
results2 = cross_validation_model(feature2, y, model)
results3 = cross_validation_model(feature3, y, model)
results4 = cross_validation_model(feature4, y, model)
results5 = cross_validation_model(feature5, y, model)
results6 = cross_validation_model(feature6, y, model)
results7 = cross_validation_model(feature7, y, model)
results8 = cross_validation_model(feature8, y, model)
results9 = cross_validation_model(feature9, y, model)
results10 = cross_validation_model(feature10, y, model)

# %%
df = pd.DataFrame({
        'feature1': results1,
        'feature2': results2,
        'feature3': results3,
        'feature4': results4,
        'feature5': results5,
        'feature6': results6,
        'feature7': results7,
        'feature8': results8,
        'feature9': results9,
        'feature10': results10
    })

df.to_excel(dir + 'results.xlsx')

# %%
df
# Out:
#            feature1  feature2  feature3  feature4  feature5  feature6  \
# Accuracy   0.960309  0.979320  0.975651  0.974650  0.982990  0.760502
# Precision  0.962588  0.979444  0.976313  0.974951  0.983186  0.762681
# Recall     0.960309  0.979320  0.975651  0.974650  0.982990  0.760502
# F1         0.960076  0.979313  0.975575  0.974613  0.982959  0.755224
# MCC        0.949851  0.973477  0.968990  0.967539  0.978250  0.691855
#
#            feature7  feature8  feature9  feature10
# Accuracy   0.959307  0.984324  0.975651   0.981655
# Precision  0.960774  0.984516  0.976109   0.981883
# Recall     0.959307  0.984324  0.975651   0.981655
# F1         0.959209  0.984300  0.975561   0.981628
# MCC        0.948148  0.979951  0.968935   0.976541
